# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent

# %%
ua = UserAgent()
headers = {"user-agent": ua.random}

url = 'https://news.naver.com/main/ranking/popularDay.naver'
res = requests.get(url, headers=headers)
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.text, 'html.parser')
# soup

# %%
print(res.text)
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
#     <meta charset="euc-kr">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="referrer" contents="always">
#     <meta http-equiv="refresh" content="600"/>
#     <meta name="viewport" content="width=1106"/>
#     <meta name="format-detection" content="telephone=no"/>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta property="og:title"       content="네이버 뉴스">
# <meta property="og:type"        content="website">
# <meta property="og:url"         content="https://news.naver.com/main/home.naver">
# <meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png"/>
# <meta property="og:description" content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공">
# <meta property="og:article:author"	content="네이버"/>
#
# <meta name="twitter:card"		content="summary">
# <meta name="twitter:title"		content="네이버 뉴스">
# <meta name="twitter:site"       content="네이버 뉴스">
# <meta name="twitter:creator"    content="네이버 뉴스">
# <meta name="twitter:image"		content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# <meta name="twitter:description" content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공">
#
#
#     <title>랭킹뉴스 : 네이버 뉴스</title>
#     <link rel="shortcut icon" type="image/x-icon" href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" />
#
#
#
#
#
#
#
#
#
#
#
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/css/common.css"/>
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/css/news.css"/>
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/js/news.jindo.js" charset="euc-kr"></script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/js/news.jquery.js" charset="utf-8"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='tvh';
# var _MAIN_NEWS_SECTION_ID='';
# var ccsrv='cc.naver.com';
# var g_ssc='news.ranking';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness=3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
# var gnb_item_hide_option=128;
#
# var gnb_timestamp = "Thu Sep 26 14:02:14 KST 2024";
# </script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20240829_170913/js/news.service.js" charset="euc-kr"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
#
#
#
# </head>
# <body>
# <div id="wrap">
#     <!-- 광고적용 태그 추가 -->
#     <div id="da_base"></div>
#     <div id="da_stake"></div>
#
#
#
# <div id="header" class="header">
#
# 	<div id="u_skip">
# 		<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# 		<a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# 	</div>
#
#
# 	<div class="snb_area">
# 		<div class="snb_inner">
#
# <div class="gnb_area">
#    <div class="gnb_wrap">
#
#       <div id="gnb" class="gnb_dark_type2"></div>
#
#    </div>
#    <div class="gnb_search is_hidden _search_content">
#    </div>
#    <div id="gnb_search_tool" class="gnb_tool">
#       <a href="javascript:;" class="tool_button _search_content_toggle_btn nclicks(gnb.sch)"><span class="icon_search">검색</span></a>
#    </div>
# </div>
#
#
#
# <div id="snb_wrap">
#     <h1>
#         <a href="https://www.naver.com/" class="h_logo nclicks(gnb.naver)"><span class="blind">NAVER</span></a>
#         <a href="/" class="h_news nclicks(gnb.news)"><span class="blind">뉴스</span></a>
#     </h1>
#     <ul class="snb_related_service">
#         <li><span class="snb_bdr"></span><a href="https://entertain.naver.com/home" class="entertain nclicks(gnb.enter)">TV연예</a></li>
#         <li><span class="snb_bdr"></span><a href="https://sports.news.naver.com" class="sports nclicks(gnb.sports)">스포츠</a></li>
#         <li><span class="snb_bdr"></span><a href="https://weather.naver.com" class="weather nclicks(gnb.weather)">날씨</a></li>
#         <li><span class="snb_bdr"></span><a href="https://contents.premium.naver.com" class="premium nclicks(gnb.premium)">프리미엄</a></li>
#     </ul>
# </div>
#
# 		</div>
# 	</div>
# 	<div class="lnb_area">
# 		<div class="lnb_inner">
#
#
#
#
#
#
#
# <div class="lnb_both">
# 	<div class="lnb_left">
# 		<div id="lnb" class="lnb_menu">
# 			<ul>
# 				<li><a href="/" class="nclicks(lnb.pcmedia)"><span class="tx">언론사별</span> </a></li>
# 				<li><a href="/section/100" class="nclicks(lnb.pol)"><span class="tx">정치</span> </a></li>
# 				<li><a href="/section/101" class="nclicks(lnb.eco)"><span class="tx">경제</span> </a></li>
# 				<li><a href="/section/102" class="nclicks(lnb.soc)"><span class="tx">사회</span> </a></li>
# 				<li><a href="/section/103" class="nclicks(lnb.lif)"><span class="tx">생활/문화</span> </a></li>
# 				<li><a href="/section/105" class="nclicks(lnb.sci)"><span class="tx">IT/과학</span> </a></li>
# 				<li><a href="/section/104" class="nclicks(lnb.wor)"><span class="tx">세계</span> </a></li>
# 				<li class="on"><a href="/main/ranking/popularDay.naver?mid=etc&sid1=111" class="nclicks(lnb.rankin)"><span class="tx">랭킹</span> <span class="blind">선택됨</span></a></li>
# 				<li><a href="/newspaper/home" class="nclicks(lnb.paper)"><span class="tx">신문보기</span> </a></li>
# 				<li><a href="/opinion/home" class="nclicks(lnb.opi)"><span class="tx">오피니언</span> </a></li>
# 				<li><a href="/main/tv/index.naver?mid=tvh" class="nclicks(lnb.tv)"><span class="tx">TV</span> </a></li>
# 				<li><a href="/factcheck/main" class="nclicks(lnb.fact)"><span class="tx">팩트체크</span> </a></li>
# 				<li><a href="https://media.naver.com/algorithm" class="nclicks(lnb.algo)"><span class="tx">알고리즘 안내</span> </a></li>
# 				<li><a href="/main/ombudsman/revisionArticleList.naver?mid=omb" class="nclicks(lnb.correct)"><span class="tx">정정보도 모음</span> </a></li>
# 			</ul>
# 		</div>
# 	</div>
# </div>
#
# 		</div>
# 	</div>
#
#
#
#     <div class="lnb">
#
#
#
#
#         <span class="lnb_date"><strong>09</strong>.<strong>26</strong><span class="day">(목)</span></span>
#
#         <ul class="lnb_side" tabindex="0">
#             <li><a href="https://news.naver.com/main/officeList.naver" class="nclicks(slb.allmedia)" title="전체 언론사">전체 언론사</a></li>
#             <li><a href="https://newsstand.naver.com/" class="nclicks(slb.newsstand)" title="뉴스스탠드" target="_blank" >뉴스스탠드</a></li>
#             <li><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="nclicks(slb.library)" title="라이브러리" target="_blank">라이브러리</a></li>
#         </ul>
#     </div>
#
# </div>
#     <hr>
#
#     <div class="rankingnews _popularWelBase _persist">
#         <div class="rankingnews_head">
#     <h2 class="rankingnews_tit">언론사별 <em>랭킹뉴스</em></h2>
#     <ul class="rankingnews_tab">
#         <li class="rankingnews_tab_item nclicks('RBP.rnk')  is_selected"><a href="/main/ranking/popularDay.naver">많이 본 뉴스</a><span class="blind">선택됨</span></li>
#         <li class="rankingnews_tab_item nclicks('RBP.cmt') "><a href="/main/ranking/popularMemo.naver">댓글 많은 뉴스</a></li>
#     </ul>
#
#
#
#
#         <button type="button" class="button_rankingnews_info _infoButton nclicks('RBP.inf')">집계안내</button>
#         <div class="rankingnews_info_layer _infoLayer" style="display: none">정오~오후 1시까지 집계한 결과입니다.<br>각 언론사의 모바일 구독자수 비중이 순서에 반영됩니다.<button type="button" class="rankingnews_info_layer_close _infoCloseButton nclicks('RBP.infclose')"><span>닫기</span></button></div>
#
#
#
# </div>
#
#
#
#
#
#
#
#
#
#
# <div class="rankingnews_box_wrap _popularRanking">
#
#
#     <div class="_officeCard _officeCard0" style="display: block">
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/437/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2023/07/17/logo_437_56_20230717153920.png" width="26" height="26" alt="JTBC"></span>
#                 <strong class="rankingnews_name">JTBC</strong>
#
#                 <p class="rankingnews_tooltip _infoTooltip" style="display:block;">랭킹 결과를 더 볼 수 있어요.</p>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/437/0000411796?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">[단독] "매도 타이밍 알려드릴게"…'김 여사-도이치 공범' 오간 메시지</a>
#                         <span class="list_time ">17시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/437/0000411796?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/437/2024/09/25/411796.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                         <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/437/0000411868?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">[단도직입] 김종혁 "대통령이 양자역학 얘기하는데…'독대하자' 말 꺼낼 분위기 아니었다"</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/437/0000411868?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/437/2024/09/26/411868.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                         <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/437/0000411830?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"점심시간 임신하라"더니…"'무자녀 삶' 조장 금지" 추진하는 러시아 [소셜픽]</a>
#                         <span class="list_time ">5시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/437/0000411830?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/437/2024/09/26/411830.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                         <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/437/0000411812?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">무인점포 찾은 여학생들...키오스크 강제로 열고 '싹쓸이'</a>
#                         <span class="list_time ">8시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/437/0000411812?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/437/2024/09/26/411812.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/437/0000411827?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">메타, 10년 공들인 '스마트 안경'…스마트폰 뛰어넘을까 [소셜픽]</a>
#                         <span class="list_time ">5시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/437/0000411827?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/437/2024/09/26/411827.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                         <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/009/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/009/2018/07/20/logo_009_56_20180720194820.png" width="26" height="26" alt="매일경제"></span>
#                 <strong class="rankingnews_name">매일경제</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/009/0005370427?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“남편 외도, 새로 사귄 남친과 결별” 황정음, 새 도전 나선다는데</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/009/0005370427?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/009/2024/09/26/5370427.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/009/0005370421?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“삼성전자마저 이럴 수가, 충격적”…40대 이상 직원이 20대보다 많아, 한해 인건비 38조</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/009/0005370421?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/009/2024/09/26/5370421.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/009/0005370360?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“대체 자식들을 얼마나 다잡는거야”…한국 아이들 근시 비율이 무려</a>
#                         <span class="list_time ">3시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/009/0005370360?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/009/2024/09/26/5370360.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/009/0005370375?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“성북동 집 앞에 서 있었다” 빈지노, 30대女에 ‘깜놀’…스토킹 혐의 경찰 수사</a>
#                         <span class="list_time ">3시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/009/0005370375?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/009/2024/09/26/5370375.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/009/0005370459?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">[속보] 2028 수능 통합사회·과학 문항 첫 공개…“융합적 사고 평가”</a>
#                         <span class="list_time ">1시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/009/0005370459?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/009/2024/09/26/5370459.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/011/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_56_20220729150242.jpg" width="26" height="26" alt="서울경제"></span>
#                 <strong class="rankingnews_name">서울경제</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/011/0004396097?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"왠지 다들 안경쓰더라니"…한국 어린이들 유독 눈 나쁜 이유 알고보니</a>
#                         <span class="list_time ">15시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/011/0004396097?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/011/2024/09/25/4396097.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/011/0004396189?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"집 앞까지 찾아와" 래퍼 빈지노, '스토킹' 혐의로 30대女 고소…경찰 "수사 중"</a>
#                         <span class="list_time ">5시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/011/0004396189?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/011/2024/09/26/4396189.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/011/0004396321?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"직장 점심시간에 '성관계'하라"더니…'이것'까지 금지한다는 러시아, 뭐길래?</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/011/0004396321?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/011/2024/09/26/4396321.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/011/0004396313?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">[영상]홍수로 9일간 강 가운데 갇혔다가 '기적 생존'…"나뭇가지 잡고 강물 마시며 버텨"</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/011/0004396313?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/011/2024/09/26/4396313.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/011/0004396339?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"대통령 10·26 서거할 것"…무속인에게 듣고 전화한 남성</a>
#                         <span class="list_time ">1시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/011/0004396339?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/011/2024/09/26/4396339.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/055/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2020/10/07/logo_055_56_20201007141807.jpg" width="26" height="26" alt="SBS"></span>
#                 <strong class="rankingnews_name">SBS</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/055/0001192904?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">명품 자랑하던 16살 도영이…"다 그만두고 싶다" 알고보니</a>
#                         <span class="list_time ">6시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/055/0001192904?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/055/2024/09/26/1192904.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                         <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/055/0001192890?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"사람 떨어졌다" 신고…부천 아파트서 2명 숨진 채 발견</a>
#                         <span class="list_time ">7시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/055/0001192890?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/055/2024/09/26/1192890.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                         <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/055/0001192984?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">민주당, 김태효 파면 요구 결의안 발의…"국기에 경례 안 해"</a>
#                         <span class="list_time ">3시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/055/0001192984?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/055/2024/09/26/1192984.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/055/0001192928?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">폭우 속 강남대로 질주한 '번개맨'…휠체어 시민 도운 버스기사</a>
#                         <span class="list_time ">5시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/055/0001192928?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/055/2024/09/26/1192928.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/055/0001192902?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">선고 직전 "캠퍼스에 묻었다"…입 닫았던 금은방 강도 실토</a>
#                         <span class="list_time ">6시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/055/0001192902?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/055/2024/09/26/1192902.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                         <strong class="r_ico r_vod_small">동영상기사</strong>
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/025/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/025/2021/08/20/logo_025_56_20210820165911.png" width="26" height="26" alt="중앙일보"></span>
#                 <strong class="rankingnews_name">중앙일보</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/025/0003388583?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">성매매 건물로 1000억 벌었다? '재계 30위' 강남사옥 비밀</a>
#                         <span class="list_time ">9시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/025/0003388583?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/025/2024/09/26/3388583.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/025/0003388673?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">유인촌 "정몽규 4연임 불허할 것…홍명보는 재선임 절차 밟아야"</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/025/0003388673?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/025/2024/09/26/3388673.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/025/0003388495?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">머리는 말, 몸통은 갈치…재앙 전조 '최후의 날 물고기' 잡혔다</a>
#                         <span class="list_time ">16시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/025/0003388495?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/025/2024/09/25/3388495.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/025/0003388677?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">손담비·이규혁, 내년 4월 부모 된다…"큰 기쁨 속 태교에 집중"</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/025/0003388677?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/025/2024/09/26/3388677.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/025/0003388643?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">[단독]'육영수 특활비 장부' 국민에 공개…"1원도 사적으로 안썼다"</a>
#                         <span class="list_time ">5시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/025/0003388643?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/025/2024/09/26/3388643.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/005/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/005/2018/07/18/logo_005_56_20180718152218.png" width="26" height="26" alt="국민일보"></span>
#                 <strong class="rankingnews_name">국민일보</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/005/0001727310?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">소방서 앞 불법 주차 해놓고… “센터장 나와” 되레 호통</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/005/0001727310?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/005/2024/09/26/1727310.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/005/0001727291?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">순천 도심 길거리서 여고생 흉기에 찔려 숨져…30대 용의자 검거</a>
#                         <span class="list_time ">3시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/005/0001727291?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/005/2024/09/26/1727291.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/005/0001727269?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“월급쟁이가 만만한가”… 소득세 9.6% 늘 동안 법인세는 4.9%</a>
#                         <span class="list_time ">6시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/005/0001727269?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/005/2024/09/26/1727269.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/005/0001727165?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“경찰이 왜 들어와, 집값 떨어지게” 폴패스 반대에 곤혹</a>
#                         <span class="list_time ">13시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/005/0001727165?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/005/2024/09/26/1727165.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/005/0001727270?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“그는 번개맨”…폭우속 휠체어 보고 달려나간 버스기사</a>
#                         <span class="list_time ">5시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/005/0001727270?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/005/2024/09/26/1727270.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/015/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/015/2020/08/11/logo_015_56_20200811194037.png" width="26" height="26" alt="한국경제"></span>
#                 <strong class="rankingnews_name">한국경제</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/015/0005037141?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"김정은도 구독"…짧은 치마 입고 춤추는 北 김여정 영상 뭐길래</a>
#                         <span class="list_time ">5시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/015/0005037141?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/015/2024/09/26/5037141.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/015/0005037205?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">백종원 "할 말 많다"…'흑백요리사' 뜨길래 주식 샀더니 '잭팟' [진영기의 찐개미 찐투자]</a>
#                         <span class="list_time ">3시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/015/0005037205?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/015/2024/09/26/5037205.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/015/0005037243?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">세상에 한 대뿐인 벤츠…'페이커' 이상혁 車 보니</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/015/0005037243?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/015/2024/09/26/5037243.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/015/0005037216?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"냄비에 썩은 쥐가"…'年 20억' 강남 유명 도시락 충격 실상</a>
#                         <span class="list_time ">3시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/015/0005037216?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/015/2024/09/26/5037216.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/015/0005037230?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">"한국 '이 동네' 진짜 멋져"…영국서 극찬한 곳 알고보니</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/015/0005037230?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/015/2024/09/26/5037230.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/366/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/366/2020/12/23/logo_366_56_20201223182636.png" width="26" height="26" alt="조선비즈"></span>
#                 <strong class="rankingnews_name">조선비즈</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/366/0001020339?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">“딥페이크 속 내가 더 매력적이라면?”…'미스코리아’ 황당 질문에 발칵</a>
#                         <span class="list_time ">4시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/366/0001020339?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img src="https://mimgnews.pstatic.net/image/origin/366/2024/09/26/1020339.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/366/0001020354?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">민희진 “방시혁 심기 거슬렀다고 공개 처형…돈 줄테니 받고 나가라고”</a>
#                         <span class="list_time ">3시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/366/0001020354?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
# ...
#                         <span class="list_time ">5시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/665/0000003735?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/665/2024/09/26/3735.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#
#
#
#
#         <div class="rankingnews_box">
#             <a href="https://media.naver.com/press/145/ranking?type=popular" class="rankingnews_box_head nclicks('RBP.rnkpname')">
#                 <span class="rankingnews_thumb"><img data-src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="26" height="26" alt="레이디경향"></span>
#                 <strong class="rankingnews_name">레이디경향</strong>
#
#             </a>
#             <ul class="rankingnews_list">
#
#
#                 <li>
#                     <em class="list_ranking_num">1</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021187?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">특별한 식단·운동 없이…혈압 낮추는 20가지 방법</a>
#                         <span class="list_time ">3시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021187?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21187.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">2</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021188?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">소득 증가율 12.6%…전문직 1위 수의사</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021188?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21188.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">3</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021189?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">‘저탄소·친환경’ 기차로 떠나는 국내 여행지 4곳</a>
#                         <span class="list_time ">2시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021189?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21189.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">4</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021186?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">‘주우재 패딩’ 몽벨, 최대 20% 할인 팝업스토어 개장</a>
#                         <span class="list_time ">4시간전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021186?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/26/21186.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#                 <li>
#                     <em class="list_ranking_num">5</em>
#                     <div class="list_content">
#                         <a href="https://n.news.naver.com/article/145/0000021185?ntype=RANKING" class="list_title nclicks('RBP.rnknws')">때가 됐다, 가을 낭만 가득한 특급호텔 와인 축제 4</a>
#                         <span class="list_time ">1일전</span>
#                     </div>
#
#                     <a href="https://n.news.naver.com/article/145/0000021185?ntype=RANKING" class="list_img nclicks('RBP.rnknws')">
#                         <img data-src="https://mimgnews.pstatic.net/image/origin/145/2024/09/25/21185.jpg?type=nf70_70" width="70" height="70" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_70x70_1.png';">
#
#                     </a>
#
#                 </li>
#
#
#             </ul>
#         </div>
#
#     </div>
#
#
#
#
#
# <button type="button" class="button_rankingnews_more _moreButton nclicks('RBP.more')">다른 언론사 랭킹 더보기</button>
#
# <a href="https://news.naver.com/main/ombudsman/rankingHelp.naver?mid=omb" class="link_rankingnews_info nclicks('RBP.policy')">랭킹 뉴스 집계 기준</a>
#
# <ul class="rankingnews_date">
#
#     <li class="is_selected"><a href="/main/ranking/popularDay.naver?date=20240926" class="nclicks('RBP.date')">09월 26일(목)</a></li>
#
#     <li class=""><a href="/main/ranking/popularDay.naver?date=20240925" class="nclicks('RBP.date')">09월 25일(수)</a></li>
#
#     <li class=""><a href="/main/ranking/popularDay.naver?date=20240924" class="nclicks('RBP.date')">09월 24일(화)</a></li>
#
#     <li class=""><a href="/main/ranking/popularDay.naver?date=20240923" class="nclicks('RBP.date')">09월 23일(월)</a></li>
#
#     <li class=""><a href="/main/ranking/popularDay.naver?date=20240922" class="nclicks('RBP.date')">09월 22일(일)</a></li>
#
# </ul>
#
# <script type="text/javascript">
#     var PopularRankingManager = jindo.$Class({
#         $static: {
#             RANKING_LIST_SELECTOR: '._officeCard',
#             MORE_BUTTON_SELECTOR: '._moreButton',
#             INFO_BUTTON_SELECTOR: '._infoButton',
#             INFO_LAYER_SELECTOR: '._infoLayer',
#             INFO_CLOSE_BUTTON_SELECTOR: '._infoCloseButton',
#             INFO_TOOLTIP_SELECTOR : '._infoTooltip',
#             COOKIE_NAME_DISPLAY_INFO : 'pc_ranking_info',
#             COOKIE_VALUE_DISPLAY_INFO : 'Y'
#         },
#
#         $init: function(base) {
#             // persist restore
#             var persistHtml = Persist.getPersistedData('persist-ranking-data');
#             if (persistHtml) {
#                 jindo.$$.getSingle('._persist').innerHTML = persistHtml;
#             }
#             var persistScrollTop = Persist.getPersistedData('persist-ranking-scroll-top');
#             if (persistScrollTop) {
#                 window.scrollTo(0, persistScrollTop); // 스크롤 위치 복구
#             }
#
#             this._welBase = jindo.$Element(base);
#             this._popularRanking = jindo.$Element(this._welBase.query("._popularRanking"));
#             this._officeRankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#             this._moreButton = jindo.$Element(this._welBase.query(this.constructor.MORE_BUTTON_SELECTOR));
#             this._infoLayer = jindo.$Element(this._welBase.query(this.constructor.INFO_LAYER_SELECTOR));
#             this._infoTooltip = jindo.$Element(this._welBase.query(this.constructor.INFO_TOOLTIP_SELECTOR));
#
#             // cookie
#             this._cookieLifeDay = 1095;
#             this._cookie = jindo.$Cookie();
#
#             this._setInfoTooltipAction();
#
#             // persist save
#             Persist.addOnClickLinkListener(function(persistModel) {
#                 var persistTargetHtml = jindo.$$.getSingle('._persist').innerHTML;
#                 persistModel.set('persist-ranking-data', persistTargetHtml); // 컨텐츠 내용 저장
#                 persistModel.set('persist-ranking-scroll-top', jindo.$Document().scrollPosition().top); // 스크롤 위치 저장
#             });
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate("click", this.constructor.MORE_BUTTON_SELECTOR, jindo.$Fn(this._showMoreOfficeRanking, this).bind());
#             this._welBase.delegate("click", this.constructor.INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate("click", this.constructor.INFO_CLOSE_BUTTON_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#         },
#
#         _setInfoTooltipAction: function() {
#             var that = this;
#
#             setTimeout(function () {
#                 that._infoTooltip.hide();
#                 that._infoTooltip = null;
#             }, 5000);
#
#             this._saveCookie(this.constructor.COOKIE_NAME_DISPLAY_INFO, this.constructor.COOKIE_VALUE_DISPLAY_INFO);
#         },
#
#         _showMoreOfficeRanking: function(event) {
#             event.stopDefault();
#
#             var arrayLength = this._officeRankingListArray.length();
#             for (var i=0 ; i < arrayLength ; i++) {
#                 var rankingList = this._officeRankingListArray.get(i);
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._officeRankingListArray.length()) {
#                         break;
#                     }
#
#                     var nextRankingList = this._officeRankingListArray.get(nextIndex);
#
#                     if (nextRankingList.visible() === false) {
#                         this._loadLazyImage(nextRankingList);
#                         this._popularRanking.append(nextRankingList);
#                         nextRankingList.show();
#
#                         if (nextIndex == (arrayLength - 1)) {
#                             this._moreButton.hide();
#                         }
#                         break;
#                     }
#                 }
#             }
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._infoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._infoLayer.hide();
#         },
#
#         _loadLazyImage: function(targetList) {
#             jindo.$A(targetList.queryAll("img")).forEach(function(img){
#                 var welImg = jindo.$Element(img);
#                 var src = welImg.attr("data-src");
#                 if (src) {
#                     welImg
#                         .attr("src", src)
#                         .attr('data-src', null);
#                 }
#             });
#         },
#
#         _saveCookie : function(name, value) {
#             this._cookie.remove(name, '.naver.com', '/');
#             this._cookie.set(name, value, this._cookieLifeDay);
#         },
#
#         _getCookie : function(name) {
#             return this._cookie.get(name);
#         }
#     });
#
#     window.addEventListener("load", function() {
#         if (jindo.$$.getSingle("._popularRanking")) {
#             var popularWelBase = jindo.$$.getSingle("._popularWelBase");
#             new PopularRankingManager(popularWelBase);
#         }
#     });
# </script>
#     </div>
#
#     <hr>
#
#
#
# <hr>
# <div id="mp_footer" class="mp_footer">
#     <div class="mp_footer_inner">
#
# <div class="floating_btn" >
#     <div class="floating_inner">
#         <a href="javascript:history.back();" class="floating_btn_back"><span class="blind">이젠 페이지</span></a>
#         <a href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;" class="floating_btn_top"><span class="blind">맨위로</span></a>
#     </div>
# </div>
#
#
# <ul class="mp_footer_list">
#
#
#
#
#             <li class="mp_footer_item"><a href="https://nid.naver.com/nidlogin.login" class="mp_footer_a nclicks(fot.login)">로그인</a></li>
#
#
#     <li class="mp_footer_item"><a href="https://www.naver.com/more.html" class="mp_footer_a nclicks(fot.serviceall)">전체서비스</a></li>
#     <li class="mp_footer_item"><a href="/main/ombudsman/index.naver" class="mp_footer_a nclicks(fot.guide)">서비스안내</a></li>
#     <li class="mp_footer_item"><a href="https://help.naver.com/alias/news/news_001.naver" class="mp_footer_a nclicks(fot.report)">오류신고</a></li>
#     <li class="mp_footer_item"><a href="https://help.naver.com/alias/news/news_007.naver" class="mp_footer_a nclicks(fot.help)">고객센터</a></li>
#
#     <li class="mp_footer_item"><a href="/main/ombudsman/edit.naver?mid=omb" class="mp_footer_charge nclicks(fot.editor)">기사배열 원칙 책임자 : 김수향</a></li>
#
#     <li class="mp_footer_item"><span class="mp_footer_charge">청소년 보호 책임자 : 이정규</span></li>
# </ul>
#
#         <p class="mp_footer_copyright">이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
#
#
#         <div class="mp_footer_naverlogo"><a href="https://www.navercorp.com/" class="mp_footer_naverlogo_a nclicks(fot.navercorp)">NAVER</a></div>
#
#         <!-- -->
#
#
#     </div>
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     (function () {
#         NeloSender.init({
#             neloCollectorUrl: "https://kr-col-ext.nelo.navercorp.com/_store",
#             projectName: "P638fcb_news-front",
#             host: "real"
#         });
#     })();
#
#
#     (function () {
#         news.right.RightSideFloatingManager.init();
#     })();
#
#
#
#     (function () {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     new news.util.Calendar({
#         url: '/main/ranking/popularDay?mid=etc&date=',
#
#         selectedDate: '//',
#         minDate: '//',
#         maxDate: '//'
#     });
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     (function () {
#         window.ntm_news = window.ntm_news || [];
#
#         jindo.$Fn(function () {
#             var ntmUrl = 'https://ntm.pstatic.net/scripts/ntm_b7032129a433.js';
#
#
#
#             ntmInit(ntmUrl);
#         }).attach(window, "load");
#
#
#         var eventType = "onpageshow" in window ? "pageshow" : "load";
#         jindo.$Fn(function () {
#             var gdid = '';
#
#
#
#             ntmCustomPageViewSend({
#                 sti: '',
#                 gdid: gdid
#             })
#         }).attach(window, eventType);
#
#     })();
#
#
#
#
#
#
#     news.startup();
#
#
#     jindo.$Fn(function () {
#         var welSkip = jindo.$Element("u_skip");
#         if (welSkip === null) {
#             return;
#         }
#         welSkip.delegate("click", "a", function (weEvent) {
#             weEvent.stopDefault();
#             var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#             oWebAccessibilityUtil.moveFocus(elTarget);
#         });
#     }).attach(window, "load");
#
#
#     document.documentElement.setAttribute('data-useragent', navigator.userAgent);
# </script>
#
# </div>
# </body>
# </html>

# %% [markdown]
# 1. 언론사별 박스를 선택!!
#     > select 메서드로 여러개 선택하면 될듯
# 2. 각 박스 안에 링크들을 모두 가져와야함.
#     > 하나의 박스를 선택했을 때 그안에 링크들을 추출
# 3. 링크를 get 요청해서 html 문자열을 가져오고
# 4. 뉴스의 제목과 본문을 추출하여 저장

# %% [markdown]
# - 언론사별 뉴스 박스 선택하기

# %%
news_box_list = soup.select('._officeCard0 .rankingnews_box')
len(news_box_list)
# Out:
# 12

# %%
news_box_list[0].select_one('.rankingnews_name').text # 언론사명!!
# Out:
# 'JTBC'

# %%
news_list = news_box_list[-1].select('.rankingnews_list a.list_title') # 뉴스 링크 a 태그 리스트
news_list
# Out:
# [<a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/448/0000479468?ntype=RANKING">與 김종혁 "김홍걸 매각한 DJ 사저, 재단이 재매입?…박지원, 전재산 헌납 약속 지키길"</a>,
#  <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/448/0000479473?ntype=RANKING">장병들이 듣고 싶은 말…"감사합니다" "고생하십니다"</a>,
#  <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/448/0000479463?ntype=RANKING">野 "김건희 여사, 국정농단 의혹 한 가운데…법에 따라 기소해야"</a>,
#  <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/448/0000479470?ntype=RANKING">당정 "이공계 석사 1000명에 연 500만원 장학금 추진"</a>,
#  <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/448/0000479471?ntype=RANKING">한동훈 "野, 호남 재보궐 선거를 경매판으로 만들어"</a>]

# %%
for a_tag in news_list:
    link = a_tag["href"]
    print(link)
    break
# Out:
# https://n.news.naver.com/article/448/0000479468?ntype=RANKING

# %% [markdown]
# - 뉴스 본문 보기

# %%
res_news = requests.get(link, headers = headers)
res_news.status_code
# Out:
# 200

# %%
soup_news = BeautifulSoup(res_news.content, 'html.parser')
# soup_news

# %%
"#title_area span"

# %%
soup_news.select_one("#title_area span").text # 뉴스 제목!!!
# Out:
# '與 김종혁 "김홍걸 매각한 DJ 사저, 재단이 재매입?…박지원, 전재산 헌납 약속 지키길"'

# %%
soup_news.select_one("#newsct_article").text # 뉴스 본문!!!
# Out:
# '\n\n\t\t\t김대중 전 대통령의 동교동 사저를 김대중재단이 재매입을 추진하고 있는 것을 두고, 26일 국민의힘에서 "시민 모금해 김홍걸 전 의원에 주냐"며 "박지원 전 의원은 전재산을 헌납하라는 약속을 지키라"는 비판이 나왔다.국민의힘 김종혁 최고위원은 이날 국회에서 열린 최고위원회의에 참석해 "김대중 전 대통령의 막내 아들 김홍걸 전 의원이 100억원에 매각한 동교동 사저를 김대중재단이 모금을 통해 다시 사들인다고 한다"면서 "김 전 의원은 거액의 상속세 때문에 사저를 매각했는데, 논리가 뒤죽박죽"이라고 지적했다.김 최고위원은 "모금을 통해 동교동 사저를 매입하는 건 시민들이 김홍걸 전 의원에게 주는 것과 큰 차이가 없지 않냐"면서 "며칠 전 영면한 장기표 선생은 민주화, 노동운동으로 수년간 옥살이를 하고도 유공자 신청도 않고 보상도 받지 않았다"고 비교했다.그러면서 박지원 전 의원이 지난 8월 "동교동 사저 회수에 전재산 내놓겠다"고 말한 발언을 상기시키며 "그 약속을 꼭 지키길 바란다"고 했다.\n\t\t\n'

# %% [markdown]
# ```python
# [
#     {"언론사명": "", "뉴스제목": "", "뉴스본문": ""},
#     {"언론사명": "", "뉴스제목": "", "뉴스본문": ""},
#     {"언론사명": "", "뉴스제목": "", "뉴스본문": ""},
#     ...
# ]
# ```

# %%
ua = UserAgent()
headers = {"user-agent": ua.random}

url = 'https://news.naver.com/main/ranking/popularDay.naver'
res = requests.get(url, headers=headers)

soup = BeautifulSoup(res.content, "html.parser")

while True:
    headers = {"user-agent": ua.random}

    url = 'https://news.naver.com/main/ranking/popularDay.naver'
    res = requests.get(url, headers=headers)

    soup = BeautifulSoup(res.content, "html.parser")

    news_box_list = soup.select('._officeCard0 .rankingnews_box')
    if len(news_box_list) > 0 :
        break

news_data = [] # 모든 뉴스들을 담을 리스트



for news_box in news_box_list:
    news_list = news_box.select('.rankingnews_list a.list_title') # 뉴스 링크 a 태그 리스트
    for a_tag in news_list:
        news_dict = {} # 하나의 뉴스가 들어있는 딕셔너리
        news_dict["언론사명"] = news_box.select_one('.rankingnews_name').text # 언론사명!!

        try:
            res_news = requests.get(a_tag["href"], headers=headers)
        except Exception as e:
            print(e)
        else:
            soup_news = BeautifulSoup(res_news.content, 'html.parser')
            news_dict["뉴스제목"] = soup_news.select_one("#title_area span").text # 뉴스 제목!!!
            news_dict["뉴스본문"] = soup_news.select_one("#newsct_article").text # 뉴스 본문!!!
            news_data.append(news_dict)

# %%
len(news_data)
# Out:
# 60

# %%
import pandas as pd
pd.DataFrame(news_data)
# Out:
#       언론사명                                               뉴스제목  \
# 0   한국경제TV         "민주당, 국내 증시 포기했나"...'금투세 폐지' 압박한 한동훈 [오한마]
# 1   한국경제TV                        전국 마트가 '난리'…30% 싼 가격에 '오픈런'
# 2   한국경제TV                                "지옥 문 열리고 있다"…자제 호소
# 3   한국경제TV                           수도권行 청년, 돈은 많이 벌지만…"어쩌지"
# 4   한국경제TV                        '만물랠리' 다시 온다..."역사적 강세장 임박"
# 5      채널A  [정치시그널]장예찬 “김건희 여사, 김정숙 여사가 혼자 인도간 것 등 비교하면 억울...
# 6      채널A            “윤 대통령 10월 26일 서거” 인요한 의원실에 전화…경찰 수사 착수
# 7      채널A                      ‘종말 물고기’ 잡혔다…호주서 잡힌 거대 산갈치 화제
# 8      채널A                       “리더 키운다”며 인분 먹인 교회…목사, 실형 확정
# 9      채널A                국정원 “북, 7차 핵실험 가능성 배제 못해…美 대선 후 분석”
# 10     한겨레            김건희에 “백담사 가시라” 박지원, 불교계에 사과하면서도 “이게 민심”
# 11     한겨레                   가수 션 “승일아, 23년간 답답했지…천국선 마음껏 뛰어”
# 12     한겨레                [영상] “번개맨 같다”…폭우 속 휠체어 보자 뛰쳐나간 버스기사
# 13     한겨레               박지원 “만찬은 윤 대통령이 한 대표를 바보, 멍청이 취급한 것”
# 14     한겨레              성범죄 비웃는 미스코리아 대회 “딥페이크 속 내가 더 매력적이면?”
# 15     YTN              배춧값 고공행진에 포장김치 매출 '쑥'...배추 1포기 9,383원
# 16     YTN            "딥페이크 속 내가 더 매력적이면?"..미스코리아 대회 질문에 '공분'
# 17     YTN                    민희진 "돈 줄 테니 나가란 제안도"...하이브 "거짓"
# 18     YTN                       일부러 손 슬쩍...수백만 원 타낸 보험사기범 적발
# 19     YTN          [날씨] 주 후반 서쪽 더위 vs 동쪽 호우...다음 주 초 '한기 남하'
# 20  디지털데일리              [단독] 삼성전자, 평택 P4⋅美테일러 2공장 발주 전면 연기 통보
# 21  디지털데일리  [MBK, 고려아연 적대적 기업사냥 논란②] 中 자본에 재매각 가능성?… 경영권 분...
# 22  디지털데일리  [DD퇴근길] 린킨파크 서사에 페이커는 뒷전…전자정부 1등 한국, 클라우드 세상에선...
# 23  디지털데일리   'HBM 완판' 모건스탠리 비관론 뒤집은 '마이크론'…시장 재편 가능성 [소부장반차장]
# 24  디지털데일리           “앗! 실수”…삼성 스스로 ’갤럭시S24 FE·갤럭시탭S10’ 가격 유출
# 25    연합뉴스                 오타니 50-50 홈런공, 경매시장으로…최소 입찰가 50만달러
# 26    연합뉴스                손담비, 내년 4월 엄마 된다…"소중한 생명 만나 태교에 집중"
# 27    연합뉴스                홍수 피해 키운 주범?…폴란드 총리 '비버와 전쟁' 선포에 논란
# 28    연합뉴스                폐업 개식용농장에 마리당 최대 60만원…농가당 2억4천만원 내외
# 29    연합뉴스                2028 수능 통합사회·과학 문항 첫 공개…"융합적 사고 평가"
# 30   아시아경제               짧은 치마 입고 "줄게 다 줄게"…노래하며 춤추는 '북한 김여정'
# 31   아시아경제          "나이 들어 갑자기 생긴 '이 습관'…치매 온다는 신호" 놀라운 연구 결과
# 32   아시아경제            "기적 같은 구조"…숲에서 발견된 10대 실종 소녀, 드론 띄워 찾았다
# 33   아시아경제                              전문가들 "생수보다 수돗물"…위험 경고
# 34   아시아경제          "아이도 낳고 400만 유튜버 됐어요"…'34m 절벽추락 생존' 여성 근황
# 35    국민일보                    소방서 앞 불법 주차 해놓고… “센터장 나와” 되레 호통
# 36    국민일보                순천 도심 길거리서 여고생 흉기에 찔려 숨져…30대 용의자 검거
# 37    국민일보              “월급쟁이가 만만한가”… 소득세 9.6% 늘 동안 법인세는 4.9%
# 38    국민일보                    “경찰이 왜 들어와, 집값 떨어지게” 폴패스 반대에 곤혹
# 39    국민일보                      “그는 번개맨”…폭우속 휠체어 보고 달려나간 버스기사
# 40    이데일리                  "가을에 에어컨 조금만 더 참을걸"…역대급 폭탄 고지서 온다
# 41    이데일리         "딥페이크가 미스코리아와 무슨 상관?" 난리난 미스코리아 SNS, 무슨 일?
# 42    이데일리                 “2kg 찌겠네”…백종원이 반한 그 ‘돈가스’, 결국 일 냈다
# 43    이데일리                           6살 딸 앞에서 폭행 당한 엄마…결국 숨졌다
# 44    이데일리          "뱃속 아이까지 숨 거둬" 임신 7개월 전처 살해한 40대 '징역 40년'
# 45    서울경제        "직장 점심시간에 '성관계'하라"더니…'이것'까지 금지한다는 러시아, 뭐길래?
# 46    서울경제             "왠지 다들 안경쓰더라니"…한국 어린이들 유독 눈 나쁜 이유 알고보니
# 47    서울경제    "집 앞까지 찾아와" 래퍼 빈지노, '스토킹' 혐의로 30대女 고소…경찰 "수사 중"
# 48    서울경제             "수령님도 있는데 나도 써 볼래"…북한 주민 700만명 반한 ‘이것’
# 49    서울경제                  "대통령 10·26 서거할 것"…무속인에게 듣고 전화한 남성
# 50    조선일보          ‘짧은 치마’에 춤추는 김여정 “오물 다 줄게”… 조회수 터진 패러디 영상
# 51    조선일보             오타니의 50-50 홈런공 경매 나왔다...시작가만 6억 7000만원
# 52    조선일보       임종석 “북한 정권 붕괴 시 중·러에 의해 완벽한 영구분단…'두 국가’가 맞다”
# 53    조선일보             “여기가 카르텔 비밀기지인가”…홍명보 ‘단골빵집’에 불똥, 무슨 일?
# 54    조선일보            ﻿“좋은 책은 100번씩 반복” 18세에 美검사 된 한인 청년의 공부법
# 55  연합뉴스TV                        심야 자율주행 택시 서울 강남서 첫선…호출로 이용
# 56  연합뉴스TV              [제보23] 만취 역주행 5명 부상…아파트서 2명 숨진 채 발견 外
# 57  연합뉴스TV                       전북 대학 강의실서 여성이 난동…정신병원 입원 조치
# 58  연합뉴스TV               푸틴, 핵무기 사용조건 완화 공식화…"적 지원한 핵보유국도 대상"
# 59  연합뉴스TV                    새벽 길거리서 여고생 흉기 피습으로 숨져…30대 긴급체포
#
#                                                  뉴스본문
# 0   \n\n\n\n\n\n시청자 여러분 안녕하십니까.오전장 한방에 마무리하는 뉴스. 오...
# 1   \n\n\n\n\n\n폭염 등 영향으로 배추 가격이 최근 크게 오르자 일부 대형마트...
# 2   \n\n\n\n\n\n이스라엘과 레바논 무장정파 헤즈볼라의 전면전 가능성이 확대되는...
# 3   \n\n\n\n\n\n수도권으로 떠난 청년이 비수도권에 남은 청년보다 연간 소득이 ...
# 4   \n\n\n\n\n\n사진: 에릭 잭슨 EMJ 캐피털 설립자미국 증시가 연일 사상 ...
# 5   \n\n\n\n\n\n 장예찬 전 국민의힘 청년최고위원이 "김건희 여사가 김정숙 여...
# 6   \n\n\n\n\n\n윤석열 대통령이 지난 24일 서울 용산 대통령실 청사에서 열린...
# 7   \n\n\n\n\n\n지난주 호주 멜빌섬 앞바다에서 거대 산갈치가 잡혔다. (사진=...
# 8   \n\n\n\n\n\n대법원 교회를 운영하면서, 교인들에게 인분을 먹으라고 강요하는...
# 9   \n\n\n\n\n\n <속보>국정원 “북, 7차 핵실험 가능성 배제 못해…美 대선...
# 10  \n\n김 여사 향해 “만악의 근원”…백담사행 제안“불교계 항의 많았다…쓰레기 하차...
# 11  \n\n‘꿈’ 루게릭요양병원 완공 앞두고 숨진 박승일 추모\n\n\n\n가수 션 인...
# 12  \n\n\n\n\n\n서울시버스운송사업조합 제공지난 13일 오후 9시40분께 서울 ...
# 13  \n\n“집권 여당 대표가 대통령 앞에서 말도 못하면 바보”\n\n\n\n윤석열 대...
# 14  \n\n“성범죄마저 여성 외모 경쟁으로 소환해” 비판\n\n\n\n지난 24일 서울...
# 15  \n\n\t\t\t폭염과 폭우로 배추 가격이 치솟으면서 포장김치를 사 먹는 사람들이...
# 16  \n\n\n\n\n\n엑스미스코리아 선발대회가 참가자들에게 딥페이크와 관련한 부적절...
# 17  \n\n\t\t\t대표직 복귀를 두고 갈등을 벌이고 있는 하이브와 민희진 전 어도어...
# 18  \n\n\t\t\t[앵커]일부러 사고가 난 척 보험사기를 저지른 60대 여성이 붙잡...
# 19  \n\n\t\t\t이번 주 후반, 동풍의 영향으로 서쪽 지방에는 30도에 육박하는 ...
# 20  \n\n경기침체⋅수익성 악화에 보수적 접근…투자 계획 대폭 수정 [소부장반차장]\n...
# 21  \n\n영풍·MBK측 주당 공개매수가격 66만원→75만원으로 상향… 경영권 분쟁후,...
# 22  \n\n\t\t\t디지털데일리가 퇴근 즈음해서 읽을 수 있는 [DD퇴근길] 코너를 ...
# 23  \n\n\n\n\n\n[ⓒ마이크론][디지털데일리 배태용 기자] 최근 4분기 실적을 ...
# 24  \n\n\n\n\n\n삼성전자가 공개한 갤럭시S24 FE [사진=sammobile]...
# 25  \n\n맥과이어 시즌 70호 홈런공 '305만4천 달러' 넘을까\n\n\n\n오타니...
# 26  \n\n\n\n\n\n손담비 가수 겸 배우[에이치앤드엔터테인먼트(현 블리츠웨이스튜디...
# 27  \n\n"비버 관련 모든 조치 허용할 것"…"재난에 희생양 찾기" 비판도    \n...
# 28  \n\n농가당 평균 300∼400마리 사육…내년 1천95억원 예산 지원남겨지는 개는...
# 29  \n\n현 중3부터 도입…사회·과학 선택과목 사라지고, 동일문항 시험평가원, 예시문...
# 30  \n\n"줄게 줄게 오물 다 줄게"…北 김여정 영상 화제해당 영상, 딥페이크 기술 ...
# 31  \n\n남성 노인 저작 기능과 치매 관련성 발견돼음식은 꼭꼭 씹어 먹어야 건강하다는...
# 32  \n\n실종됐던 미국 10대 소녀, 숲 수색 중 발견드론 전문가, 실종 소식 접하고...
# 33  \n\n"인간, 지구 건강 위해 수돗물 마셔야"생수가 수돗물보다 훨씬 건강에 나쁘다...
# 34  \n\n5년 전 남편의 살해 시도로 절벽 추락해 유산피나는 노력 끝에 재활 성공"모...
# 35  \n\n\n\n\n\n지난 24일 경남 진해시 한 119 안전센터 앞에  일반 승용...
# 36  \n\n\n\n\n\n전남 순천의 도심 길거리에서 여고생을 흉기로 찔러 살해한 30...
# 37  \n\n\n\n\n\n기사의 이해를 돕기 위한 이미지. 기사 내용과 직접 관련이 없...
# 38  \n\n아파트 공동현관 자동 출입 시스템신고 후 골든타임 확보 위해 도입입주자대표회...
# 39  \n\n버스 운전 10년 경력의 이중호 기사“사람이 먼저라는 생각뿐…같은 일 일어나...
# 40  \n\n가을 늦더위에 9월 전기사용량 한여름 수준으로'공급과잉 정전' 우려했던 전력...
# 41  \n\n제68회 미스코리아 선발대회 '즉석 질문' 논란누리꾼 "딥페이크 피해자가 얼...
# 42  \n\n24일 ‘휴게소 음식 페스타’ 개최‘백종원의 3대 천왕’ 나온 한미식당,‘명...
# 43  \n\n술자리서 시비 붙은 여성 폭행해 숨져그 자리에는 여성의 딸도 있었다[이데일리...
# 44  \n\n1심서 징역 40년 선고제왕절개로 태아 구조했지만 19일 만에 숨져'심신미약...
# 45  \n\n러시아, 심각한 저출산 문제 해결 조치'자녀 없이 살기 운동' 선전 금지 법...
# 46  \n\n中 연구팀, 안과학회지 논문에서 연구 결과 공개전세계 50개국 어린이·청소년...
# 47  \n\n\n\n\n\n래퍼 빈지노(오른쪽)와 아내 스테파니 미초바. 빈지노 인스타그...
# 48  \n\n스마트폰 가입자 최대 700만명다운로드 내역 등은 당국이 통제\n\n\n\n...
# 49  \n\n인요한 의원실에 "경호 강화하라" 전화경찰, 공조 끝에 무속인과 통화내용 확...
# 50  \n\n\n\n\n\n김여정 북한 노동당 부부장이 조현아의 '줄게'에 맞춰 춤을 추...
# 51  \n\n\n\n\n\n오타니 쇼헤이(LA 다저스)가 19일 미국 플로리다주 마이애미...
# 52  \n\n“헌법에서 영토조항 삭제·개정해야””이미 명실상부 두 국가, 통일부도 필요 ...
# 53  \n\n\n\n\n\n박주호 전 대한축구협회 전력강화위원이 지난 24일 오전 서울 ...
# 54  \n\n\n\n\n\n18세 나이에 검사가 된 한인 청년 피터 박(19). /tvN...
# 55  \n\n[앵커] 오늘(26일)부터 서울시가 강남 일대에서 국내 처음으로 심야시간대 ...
# 56  \n\n\t\t\t▶ 만취 역주행 5명 부상…아파트서 2명 숨진 채 발견전북 정읍에...
# 57  \n\n\t\t\t전북 한 대학의 강의실에서 한 여성이 난동을 피워 정신병원에 응급...
# 58  \n\n\t\t\t[앵커] 블라디미르 푸틴 러시아 대통령이 핵무기 사용 기준을 완화...
# 59  \n\n\t\t\t도심 길거리에서 10대 여고생을 흉기로 찔러 숨지게 한 뒤 달아난...
