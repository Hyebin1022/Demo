# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import pandas as pd
from tqdm import tqdm
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# device = "cuda" if torch.cuda.is_available() else "cpu"
# model.to(device)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 긍*부정 분류

# %%
import pandas as pd
import numpy as np
import torch
from tqdm.auto import tqdm
import random
import os

def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

DATA_PATH = "/content/drive/MyDrive/멋쟁이사자차럼/data/"
SEED = 42

device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
train = pd.read_csv(f"{DATA_PATH}review_train.csv")
test = pd.read_csv(f"{DATA_PATH}review_test.csv")

train.shape, test.shape
train
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   object
#  1   review  2000 non-null   object
#  2   target  2000 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 47.0+ KB

# %%
# %pip install kiwipiepy
from kiwipiepy import Kiwi
text = train["review"][0]
text

# %%
kiwi = Kiwi()
result = kiwi.tokenize(train["review"])
train_list = [ [ t.form for t in tokens ] for tokens in result ]
result = kiwi.tokenize(test["review"])
test_list = [ [ t.form for t in tokens ] for tokens in result ]
from sklearn.feature_extraction.text import TfidfVectorizer
vec = TfidfVectorizer(max_features=500)
train_data = vec.fit_transform(
    [ " ".join(t) for t in train_list ]
).A
test_data = vec.transform(
    [ " ".join(t) for t in test_list ]
).A
train_data.shape, test_data.shape
(train_data.sum(axis=1) == 0).sum()
target = train["target"].to_numpy().reshape(-1, 1)
target.shape
# Out:
# (2000, 1)

# %% [markdown]
# ## 데이터셋

# %%
class ReviewDataset(torch.utils.data.Dataset):
    def __init__(self, x, y=None):
        self.x , self.y = x, y

    def __len__(self):
        return self.x.shape[0]

    def __getitem__(self, i):
        item = {}
        item["x"] = torch.Tensor(self.x[i])
        if self.y is not None:
            item["y"] = torch.Tensor(self.y[i])
        return item
dt = ReviewDataset(train_data,target)
dl= torch.utils.data.DataLoader(dt, batch_size=2)
batch = next(iter(dl))
batch

# %% [markdown]
# ## 모델 클래스

# %%
class ResidualBlock(torch.nn.Module):
    def __init__(self, in_features):
        super().__init__()
        self.fx = torch.nn.Sequential(
            torch.nn.Linear(in_features, in_features),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.5),
            torch.nn.Linear(in_features, in_features)
        )
        self.relu = torch.nn.ReLU()

    def forward(self, x):
        fx = self.fx(x)
        hx = fx + x
        return self.relu(hx)
class Net(torch.nn.Module):
    def __init__(self, in_features, n_layers=8):
        super().__init__()

        self.init_layer = torch.nn.Sequential(
            torch.nn.Linear(in_features, in_features // 2),
            torch.nn.BatchNorm1d(in_features // 2),
            torch.nn.LeakyReLU()
        )
        res_list = [ ResidualBlock(in_features//2) for _ in range(n_layers) ]
        self.seq = torch.nn.Sequential(*res_list)
        self.output_layer = torch.nn.Linear(in_features//2, 1)

    def forward(self, x):
        x = self.init_layer(x)
        x = self.seq(x)
        return self.output_layer(x)
Net(train_data.shape[1])(batch["x"])
# Out:
# tensor([[-0.5295],
#         [-0.6667]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## 학습 루프

# %%
def train_loop(dl, model, loss_fn, optimizer, device):
    epoch_loss = 0
    model.train()
    for batch in dl:
        pred = model(batch["x"].to(device))
        loss = loss_fn(pred, batch["y"].to(device))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    epoch_loss /= len(dl)
    return epoch_loss

# %% [markdown]
# ## 테스트 루프

# %%
@torch.no_grad()
def test_loop(dl, model, loss_fn, device):
    epoch_loss = 0
    model.eval()

    act = torch.nn.Sigmoid()
    pred_list = []
    for batch in dl:
        pred = model( batch["x"].to(device) )
        if batch.get("y") is not None:
            loss = loss_fn(pred, batch["y"].to(device) )
            epoch_loss += loss.item()

        pred = act(pred)
        pred = pred.to("cpu").numpy()
        pred_list.append(pred)

    pred = np.concatenate(pred_list)
    epoch_loss /= len(dl)
    return epoch_loss, pred

# %% [markdown]
# ## 학습하기

# %%
n_splits = 5
batch_size = 32
epochs = 100
loss_fn = torch.nn.BCEWithLogitsLoss()

from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
cv = KFold(n_splits, shuffle=True, random_state=SEED)
is_holdout = False
reset_seeds(SEED)
score_list = []
for i, (tri, vai) in enumerate(cv.split(train_data)):
    # 학습 데이터
    train_dt = ReviewDataset(train_data[tri], target[tri])
    train_dl = torch.utils.data.DataLoader(train_dt, batch_size=batch_size, shuffle=True)
    # 검증 데이터
    valid_dt = ReviewDataset(train_data[vai], target[vai])
    valid_dl = torch.utils.data.DataLoader(valid_dt, batch_size=batch_size, shuffle=False)

    # 모델 객체 및 옵티마이저 생성
    model = Net(train_data.shape[1]).to(device)
    optimizer = torch.optim.Adam( model.parameters() )

    patience = 0 # 조기 종료 조건을 주기 위한 변수
    best_score = 0 # 현재 최고점수
    for _ in tqdm(range(epochs)):
        train_loss = train_loop(train_dl, model, loss_fn, optimizer, device)
        valid_loss, pred = test_loop(valid_dl, model, loss_fn, device)
        pred = np.where(pred > 0.5, 1, 0)
        score = accuracy_score(target[vai], pred)
        print(train_loss, valid_loss, score)

        patience += 1
        if score > best_score:
            best_score = score
            patience = 0
            torch.save( model.state_dict(), f"model{i}.pt" )

        if patience == 10:
            break

    score_list.append(best_score)
    print(f"ACC 최고점수: {best_score}")

    if is_holdout:
        break
print(score_list)
print(np.mean(score_list))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.6260003209114074 0.5925454405637888 0.695
# 0.379820748269558 0.6105662721853989 0.7125
# 0.26754079788923263 0.6897672002132123 0.7375
# 0.1563432063162327 0.8922322564400159 0.715
# 0.13917258907109498 1.0078993554298694 0.7275
# 0.14890590753406285 0.815742436509866 0.7025
# 0.156663689725101 0.9710836593921368 0.7025
# 0.1479032376408577 1.3063740844909961 0.7
# 0.17703445203602314 0.682049444088569 0.6925
# 0.1635565023124218 0.9010361387179449 0.685
# 0.12212781194597483 1.0967345879628108 0.69
# 0.10248114230344071 1.3402236172786126 0.7025
# 0.12383770775049925 1.172918134010755 0.6925
# ACC 최고점수: 0.7375
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.628304991722107 0.5954232445129981 0.7525
# 0.3878269359469414 0.5100278453185008 0.74
# 0.29675365768373013 0.6154235097078177 0.7525
# 0.22123784929513932 0.7782755700441507 0.7425
# 0.216577732488513 1.1273493354137127 0.7275
# 0.16998404145240784 0.9165945442823263 0.7225
# 0.14857698656618595 1.1132087363646581 0.7325
# 0.1672697953879833 0.9669479750669919 0.7275
# 0.12981294900178908 0.9978178418599642 0.71
# 0.13078484300523996 0.8576521437901717 0.735
# 0.13966008685529233 1.2096684208283057 0.7225
# ACC 최고점수: 0.7525
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.6642198544740677 0.5948674495403583 0.7475
# 0.4184854620695114 0.561614488179867 0.72
# 0.2798328714072704 0.6347491557781513 0.745
# 0.19114400312304497 0.8473711862013891 0.745
# 0.2078106202930212 0.8849363900147952 0.7225
# 0.14876782663166524 0.9523641432707126 0.7325
# 0.17062129363417625 1.0509078594354482 0.745
# 0.13576409161090852 1.1649943360915551 0.7425
# 0.16012893240898848 0.8926766721101907 0.7425
# 0.12906271897256374 1.287862733579599 0.7375
# 0.1517935087531805 1.0358810837452228 0.75
# 0.13139153217896818 0.8038533708223929 0.745
# 0.1751857240498066 1.047303855419159 0.72
# 0.14816871456801892 1.1960475811591516 0.735
# 0.139954680390656 1.2749497111027057 0.7375
# 0.13069343231618405 1.379403327520077 0.725
# 0.11586355868726969 1.3721713515428395 0.7425
# 0.11306424800306558 1.3565188073194945 0.7375
# 0.1095341221243143 1.3353846004376044 0.72
# 0.11848981844261289 1.4961209274255312 0.7375
# 0.12889645154820756 1.73997108065165 0.7275
# ACC 최고점수: 0.75
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.6230823534727097 0.5793119439711938 0.7325
# 0.3807615339756012 0.5555983942288619 0.7225
# 0.2577189654111862 0.6313256323337555 0.725
# 0.18841964587569238 0.7338531429951007 0.7175
# 0.168511633425951 0.7756723165512085 0.6875
# 0.15561677128076554 0.8259520484850957 0.705
# 0.13779956076294184 1.1796976923942566 0.695
# 0.14126431873068213 0.9004086508200719 0.69
# 0.14739614255726338 1.0362345392887409 0.6975
# 0.15704521991312503 1.0173881604121282 0.71
# 0.104984563998878 0.9668565942690923 0.705
# ACC 최고점수: 0.7325
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0.6312319874763489 0.5774480196145865 0.73
# 0.40092132151126864 0.53205629495474 0.725
# 0.24804230347275735 0.6905173796873826 0.73
# 0.21048673287034034 0.7514290970105392 0.7275
# 0.1744207288324833 0.778675187092561 0.7275
# 0.19104268342256547 1.4477126323259795 0.72
# 0.1541249580681324 1.1337340336579542 0.715
# 0.1373986041545868 1.5294681856265435 0.7275
# 0.14331772286444902 1.7673752216192393 0.725
# 0.1400418544560671 1.1257527608137865 0.755
# 0.13947141848504543 1.404688468346229 0.745
# 0.19706335794180632 0.8127730488777161 0.7225
# 0.11796038679778575 1.8310037897183344 0.7325
# 0.16969131004065274 1.1795270580511827 0.7375
# 0.10699086855631322 1.3543335657853346 0.7275
# 0.11324104625731707 1.5654681554207435 0.7125
# 0.10806102165952325 2.0845795961526723 0.7025
# 0.10741430275142193 1.8120651566065276 0.7075
# 0.1343352037668228 1.2887794879766612 0.725
# 0.10168681403622032 1.5512618743456328 0.7175
# ACC 최고점수: 0.755
# [0.7375, 0.7525, 0.75, 0.7325, 0.755]
# 0.7455

# %% [markdown]
# ## 예측하기

# %%
test_dt = ReviewDataset(test_data)
test_dl = torch.utils.data.DataLoader(test_dt, shuffle=False, batch_size=batch_size)
pred_list = []
for i in range(n_splits):
    model = Net(train_data.shape[1]).to(device)
    state_dict = torch.load(f"model{i}.pt", weights_only=True)
    model.load_state_dict(state_dict)

    _, pred = test_loop(test_dl, model, None, device)
    pred_list.append(pred)
pred = np.mean(pred_list, axis=0)
pred = np.where(pred>0.5, 1, 0)
pred.shape

# %% [markdown]
# # 맞춤법 교정한 파일 가져오기

# %%
# 3. 엑셀 파일에서 데이터 읽기
file_path = '/content/drive/MyDrive/멋쟁이사자차럼/data/신흥시장_맞춤법교정완료파일.xlsx'
df = pd.read_excel(file_path)

# %%
len(df)
# Out:
# 8728

# %%
df
# Out:
#      source          id                                             review  \
# 0      eave        부니86             분위기도 너무 좋고 따뜻한 공간이에요 😚 재방문 의사 100%입니다.
# 1      eave        정열75                             카페 분위기도 좋고 커피도 맛있습니다!.
# 2      eave  guri093099                                        넘 맛있어요 >_<.
# 3      eave     dld****                                          해방촌 eave.
# 4      eave       토리629                         매장도 너무 깔끔하고 친절하시고 맛있어요 🤍🤍.
# ...     ...         ...                                                ...
# 8723     흑해         메리0  여기 짱 맛있어요! 저희가 밀크티랑 화연만 화학 연구원이 만드는 에이드를 시켰는데 ...
# 8724     흑해         생각씨  날씨 더웠는데 해방촌 올라오자마자 흑해 카페에서 화연만 에이드 마셨어요! 에이드 줜...
# 8725     흑해      Skun21  터키식 커피? 홍차? 메네멘? 카이막까지 맛볼 수 있는 흑해 🤩 저번에 터키 커피랑...
# 8726     흑해  AD ASTRA57  멜랑꼴리한 날 편하게 이색적인 안주랑 너무 무겁지 않은 세 미스 위트 와인이랑 혼술...
# 8727     흑해  Jeliboldin  여기 카이막 진짜 전국 맛이~~ 터키 커피랑 맛있게 먹었음 분위기도 좋고 사장님도 ...
#
#            date revisit               source_file
# 0       12.17.화  1번째 방문  eave_2024-12-23_14-14-12
# 1       12.16.월  1번째 방문  eave_2024-12-23_14-14-12
# 2       12.14.토  1번째 방문  eave_2024-12-23_14-14-12
# 3       12.14.토  1번째 방문  eave_2024-12-23_14-14-12
# 4       12.13.금  1번째 방문  eave_2024-12-23_14-14-12
# ...         ...     ...                       ...
# 8723   23.7.1.토  1번째 방문    흑해_2024-12-23_14-24-02
# 8724   23.7.1.토  1번째 방문    흑해_2024-12-23_14-24-02
# 8725   23.7.1.토  1번째 방문    흑해_2024-12-23_14-24-02
# 8726  23.6.29.목  1번째 방문    흑해_2024-12-23_14-24-02
# 8727  23.6.29.목  1번째 방문    흑해_2024-12-23_14-24-02
#
# [8728 rows x 6 columns]

# %%
df['clean_review']= df['review'].str.replace("[^\w ]+", "", regex=True).str.lower()

# %%
filtered_data =df[df['clean_review'].str.len() >= 3]  # 길이 3미만 리뷰 제거

# %% [markdown]
# - 한글 리뷰만 남기고 다 제거해보기

# %%
import re  # re 모듈 임포트

# %%
def extract_word(text):
    hangul = re.compile('[^가-힣]')
    result = hangul.sub(' ', text)
    return result

# %%
df['clean_review'] = df['clean_review'].apply(lambda x:extract_word(x))

# %% [markdown]
# ## 키워드 추출

# %%
# %pip install konlpy
from konlpy.tag import Okt, Komoran, Hannanum, Kkma
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (5.3.0)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 94.7 MB/s eta 0:00:00
# Downloading jpype1-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (493 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 493.8/493.8 kB 41.3 MB/s eta 0:00:00
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.1 konlpy-0.6.0

# %%
okt = Okt()
words = " ".join(df['clean_review'].tolist())
words = okt.morphs(words,stem=True)

# %%
len(words)
# Out:
# 121036

# %%
# 한글자 제거
remove_one_word = [x for x in words if len(x)>1 ]
len(remove_one_word)
# Out:
# 84354

# %%
# 단어별 빈도를 확인
from collections import Counter
frequent = Counter(remove_one_word).most_common()

# %%
frequent
# Out:
# [('좋다', 4203),
#  ('맛있다', 3772),
#  ('하다', 2672),
#  ('너무', 2455),
#  ('있다', 1637),
#  ('커피', 1452),
#  ('카페', 1193),
#  ('먹다', 1189),
#  ('오다', 1053),
#  ('분위기', 1011),
#  ('친절하다', 969),
#  ('보다', 810),
#  ('가다', 748),
#  ('이다', 747),
#  ('해방촌', 725),
#  ('맛집', 686),
#  ('디저트', 669),
#  ('사장', 643),
#  ('같다', 579),
#  ('음료', 579),
#  ('넘다', 576),
#  ('예쁘다', 568),
#  ('진짜', 526),
#  ('방문', 490),
#  ('에서', 485),
#  ('루프', 464),
#  ('케이크', 463),
#  ('자다', 458),
#  ('싶다', 449),
#  ('정말', 444),
#  ('귀엽다', 366),
#  ('이에요', 357),
#  ('인테리어', 356),
#  ('많다', 351),
#  ('라테', 345),
#  ('으로', 335),
#  ('하고', 325),
#  ('않다', 304),
#  ('없다', 300),
#  ('이쁘다', 290),
#  ('들다', 288),
#  ('자리', 265),
#  ('공간', 264),
#  ('되다', 260),
#  ('아늑하다', 259),
#  ('최고', 256),
#  ('예요', 250),
#  ('남산', 250),
#  ('추천', 245),
#  ('다음', 244),
#  ('매장', 243),
#  ('시간', 239),
#  ('인데', 233),
#  ('나오다', 230),
#  ('사진', 224),
#  ('메뉴', 221),
#  ('사람', 220),
#  ('수플레', 219),
#  ('이라', 215),
#  ('음식', 215),
#  ('직원', 215),
#  ('크림', 211),
#  ('친구', 206),
#  ('가격', 206),
#  ('여기', 204),
#  ('까지', 192),
#  ('많이', 191),
#  ('조용하다', 189),
#  ('주다', 186),
#  ('들어가다', 181),
#  ('크루', 180),
#  ('좋아하다', 176),
#  ('완전', 174),
#  ('자주', 165),
#  ('보고', 164),
#  ('그리고', 164),
#  ('가게', 163),
#  ('엄청', 163),
#  ('느낌', 162),
#  ('주문', 160),
#  ('생각', 158),
#  ('기분', 152),
#  ('아쉽다', 152),
#  ('멋지다', 150),
#  ('찾다', 148),
#  ('날씨', 148),
#  ('앉다', 144),
#  ('카이', 143),
#  ('다른', 142),
#  ('처음', 141),
#  ('이랑', 141),
#  ('보이다', 139),
#  ('아니다', 137),
#  ('시키다', 135),
#  ('갈다', 131),
#  ('분들', 130),
#  ('말다', 129),
#  ('다양하다', 128),
#  ('비싸다', 128),
#  ('아주', 127),
#  ('계단', 125),
#  ('넓다', 124),
#  ('깔끔하다', 122),
#  ('쿠키', 122),
#  ('특히', 121),
#  ('편하다', 121),
#  ('마시다', 120),
#  ('시원하다', 120),
#  ('만들다', 119),
#  ('따뜻하다', 116),
#  ('에는', 116),
#  ('종류', 115),
#  ('즐기다', 114),
#  ('크다', 113),
#  ('조금', 113),
#  ('나다', 112),
#  ('아메리카노', 111),
#  ('초코', 110),
#  ('힐링', 109),
#  ('그냥', 108),
#  ('그렇다', 107),
#  ('베이글', 107),
#  ('부드럽다', 105),
#  ('마다', 105),
#  ('들어오다', 103),
#  ('밀크', 102),
#  ('테라스', 101),
#  ('올라가다', 100),
#  ('샌드위치', 100),
#  ('타워', 100),
#  ('들르다', 98),
#  ('바로', 98),
#  ('되어다', 98),
#  ('하나', 98),
#  ('야경', 98),
#  ('덥다', 95),
#  ('달달', 94),
#  ('내부', 94),
#  ('데이트', 94),
#  ('찍다', 94),
#  ('브런치', 94),
#  ('동네', 93),
#  ('오늘', 93),
#  ('에도', 93),
#  ('생기다', 93),
#  ('테이블', 92),
#  ('감성', 92),
#  ('부터', 91),
#  ('다시', 91),
#  ('보내다', 91),
#  ('거북이', 91),
#  ('강아지', 90),
#  ('노을', 90),
#  ('괜찮다', 90),
#  ('우연히', 88),
#  ('오픈', 88),
#  ('이고', 88),
#  ('근처', 87),
#  ('대화', 86),
#  ('정도', 86),
#  ('딸기', 86),
#  ('받다', 85),
#  ('같이', 84),
#  ('이드', 82),
#  ('레몬', 82),
#  ('직접', 81),
#  ('존맛', 81),
#  ('주스', 81),
#  ('주말', 79),
#  ('음악', 79),
#  ('이네', 79),
#  ('실내', 78),
#  ('푸딩', 78),
#  ('산도', 77),
#  ('감사하다', 76),
#  ('돼다', 76),
#  ('강추', 76),
#  ('가면', 76),
#  ('신흥시장', 75),
#  ('버터', 74),
#  ('고소하다', 73),
#  ('낭시', 72),
#  ('특별하다', 72),
#  ('굿굿', 72),
#  ('치즈케이크', 72),
#  ('비건', 72),
#  ('느껴지다', 71),
#  ('이용', 71),
#  ('터키', 71),
#  ('먹기', 70),
#  ('포장', 70),
#  ('평일', 69),
#  ('좌석', 69),
#  ('모찌', 69),
#  ('어울리다', 68),
#  ('아기자기하다', 67),
#  ('항상', 67),
#  ('빙수', 67),
#  ('치즈', 67),
#  ('모르다', 66),
#  ('가성', 65),
#  ('미치다', 65),
#  ('없이', 64),
#  ('놀다', 64),
#  ('신선하다', 64),
#  ('요즘', 63),
#  ('편안하다', 63),
#  ('차다', 63),
#  ('빵집', 63),
#  ('근데', 63),
#  ('역시', 62),
#  ('기다리다', 62),
#  ('서울', 62),
#  ('좁다', 62),
#  ('모두', 61),
#  ('발견', 61),
#  ('진하다', 61),
#  ('별로', 61),
#  ('야외', 61),
#  ('행복하다', 61),
#  ('무스', 61),
#  ('리뷰', 60),
#  ('제일', 60),
#  ('여서', 60),
#  ('아이스크림', 60),
#  ('털실', 60),
#  ('적당하다', 59),
#  ('장소', 59),
#  ('저녁', 59),
#  ('위치', 58),
#  ('말차', 58),
#  ('무엇', 58),
#  ('꾸꾸', 58),
#  ('혼자', 57),
#  ('저렴하다', 57),
#  ('화장실', 57),
#  ('한잔', 57),
#  ('기대', 56),
#  ('지만', 56),
#  ('달다', 56),
#  ('주시', 56),
#  ('유명하다', 56),
#  ('독특하다', 56),
#  ('가보다', 55),
#  ('지나가다', 55),
#  ('새롭다', 55),
#  ('다녀오다', 55),
#  ('들리다', 54),
#  ('힘들다', 54),
#  ('소금', 54),
#  ('노래', 53),
#  ('이렇다', 53),
#  ('토스트', 53),
#  ('이렇게', 52),
#  ('찍기', 52),
#  ('느끼다', 52),
#  ('불편하다', 52),
#  ('오랜', 52),
#  ('계속', 51),
#  ('함께', 51),
#  ('과일', 51),
#  ('깨끗하다', 50),
#  ('상큼', 50),
#  ('바질', 50),
#  ('쉬다', 49),
#  ('대박', 49),
#  ('여기다', 49),
#  ('웨이', 49),
#  ('여러', 49),
#  ('알다', 49),
#  ('다만', 49),
#  ('프렌치토스트', 49),
#  ('꾸다', 48),
#  ('서비스', 48),
#  ('에스프레소', 48),
#  ('때문', 48),
#  ('아이스', 47),
#  ('이태원', 47),
#  ('그래도', 47),
#  ('보기', 47),
#  ('드리다', 46),
#  ('찌다', 46),
#  ('단골', 46),
#  ('작다', 46),
#  ('멋있다', 46),
#  ('손님', 46),
#  ('하지만', 46),
#  ('특이하다', 46),
#  ('신기하다', 45),
#  ('구경', 45),
#  ('건강하다', 45),
#  ('맛보다', 45),
#  ('늦다', 45),
#  ('고구마', 45),
#  ('가능하다', 44),
#  ('산미', 44),
#  ('지다', 44),
#  ('쓰다', 44),
#  ('재밌다', 44),
#  ('피자', 44),
#  ('옥상', 44),
#  ('여유', 43),
#  ('처럼', 43),
#  ('라서', 43),
#  ('가기', 43),
#  ('일찍', 43),
#  ('인생', 43),
#  ('플레', 43),
#  ('놀라다', 42),
#  ('무조건', 42),
#  ('가요', 42),
#  ('경치', 42),
#  ('콘셉트', 42),
#  ('아침', 42),
#  ('취향', 41),
#  ('자체', 41),
#  ('번째', 41),
#  ('비주', 41),
#  ('께서', 40),
#  ('쾌적하다', 40),
#  ('적다', 40),
#  ('창가', 40),
#  ('밖에', 40),
#  ('추가', 40),
#  ('드립', 40),
#  ('만큼', 39),
#  ('인스타', 39),
#  ('맞다', 39),
#  ('바닐라', 39),
#  ('찾아가다', 39),
#  ('쏘다', 39),
#  ('골목', 38),
#  ('즐겁다', 38),
#  ('예약', 38),
#  ('내다', 38),
#  ('입맛', 37),
#  ('편이', 37),
#  ('맥주', 37),
#  ('일단', 37),
#  ('오렌지', 37),
#  ('원두', 36),
#  ('드디어', 36),
#  ('레몬에이드', 36),
#  ('줄다', 36),
#  ('생각나다', 36),
#  ('용산', 36),
#  ('모양', 36),
#  ('풍경', 36),
#  ('입구', 36),
#  ('가세', 36),
#  ('메다', 36),
#  ('오후', 35),
#  ('라고', 35),
#  ('남자', 35),
#  ('나서다', 35),
#  ('보이', 35),
#  ('토마토', 35),
#  ('트이다', 35),
#  ('무난', 35),
#  ('가지', 35),
#  ('착즙', 35),
#  ('만족하다', 34),
#  ('웨이팅', 34),
#  ('모든', 34),
#  ('추다', 34),
#  ('조합', 34),
#  ('우유', 34),
#  ('버리다', 34),
#  ('얼그레이', 34),
#  ('재료', 34),
#  ('짜다', 34),
#  ('편지', 34),
#  ('인상', 34),
#  ('꾸미다', 33),
#  ('춥다', 33),
#  ('시장', 33),
#  ('굉장하다', 33),
#  ('추하다', 33),
#  ('이라고', 33),
#  ('번창', 32),
#  ('타르트', 32),
#  ('찾아오다', 32),
#  ('이번', 32),
#  ('식사', 32),
#  ('불친절하다', 32),
#  ('장님', 32),
#  ('눕다', 32),
#  ('파스타', 32),
#  ('다쿠아즈', 32),
#  ('전체', 31),
#  ('매우', 31),
#  ('되게', 31),
#  ('남기다', 31),
#  ('주차', 31),
#  ('와인', 31),
#  ('잇다', 31),
#  ('페인', 30),
#  ('이나', 30),
#  ('놓다', 30),
#  ('여름', 30),
#  ('매력', 30),
#  ('의사', 29),
#  ('아아', 29),
#  ('이야기', 29),
#  ('읽다', 29),
#  ('디카', 29),
#  ('수제', 29),
#  ('올라오다', 29),
#  ('사다', 29),
#  ('자리다', 29),
#  ('이름', 29),
#  ('건지다', 29),
#  ('몽블랑', 29),
#  ('진동', 29),
#  ('소리', 28),
#  ('화이트', 28),
#  ('좋아지다', 28),
#  ('에요', 28),
#  ('양도', 28),
#  ('궁금하다', 28),
#  ('에게', 28),
#  ('아깝다', 28),
#  ('특색', 28),
#  ('거리', 28),
#  ('브라우니', 28),
#  ('착하다', 28),
#  ('따다', 28),
#  ('전망', 28),
#  ('오래', 28),
#  ('프리', 28),
#  ('가득하다', 28),
#  ('연어', 28),
#  ('테린느', 28),
#  ('오랑', 28),
#  ('크리스마스', 27),
#  ('만족스럽다', 27),
#  ('가장', 27),
#  ('햇살', 27),
#  ('후암동', 27),
#  ('완벽하다', 27),
#  ('마음', 27),
#  ('여자', 27),
#  ('딱이다', 27),
#  ('그만큼', 27),
#  ('대기', 27),
#  ('우시', 27),
#  ('차분하다', 26),
#  ('한적하다', 26),
#  ('이유', 26),
#  ('얘기', 26),
#  ('고르다', 26),
#  ('나가다', 26),
#  ('쓸다', 26),
#  ('생크림', 26),
#  ('바람', 26),
#  ('지인', 26),
#  ('고급', 26),
#  ('바스크', 26),
#  ('파운드', 26),
#  ('타자기', 26),
#  ('보통', 25),
#  ('시끄럽다', 25),
#  ('추억', 25),
#  ('오기', 25),
#  ('기대하다', 25),
#  ('저희', 25),
#  ('살짝', 25),
#  ('높다', 25),
#  ('끄다', 25),
#  ('얼음', 25),
#  ('인지', 25),
#  ('칵테일', 25),
#  ('가득', 25),
#  ('피클', 25),
#  ('의자', 24),
#  ('찾기', 24),
#  ('마시기', 24),
#  ('팔다', 24),
#  ('걷다', 24),
#  ('재미', 24),
#  ('후르', 24),
#  ('한데', 24),
#  ('원래', 24),
#  ('최애', 24),
#  ('넣다', 24),
#  ('글루텐', 24),
#  ('다포딜', 24),
#  ('고민', 23),
#  ('하루', 23),
#  ('아래', 23),
#  ('플랫', 23),
#  ('우드', 23),
#  ('쫀득', 23),
#  ('전부', 23),
#  ('주변', 23),
#  ('구매', 23),
#  ('느끼하다', 23),
#  ('남다', 23),
#  ('망고', 23),
#  ('샐러드', 23),
#  ('원하다', 23),
#  ('개다', 23),
#  ('여행', 23),
#  ('일몰', 23),
#  ('이지만', 23),
#  ('해방', 23),
#  ('감상', 23),
#  ('어떻다', 23),
#  ('자몽', 23),
#  ('티라미수', 23),
#  ('녹다', 23),
#  ('치킨', 23),
#  ('작업', 22),
#  ('스타일', 22),
#  ('수다', 22),
#  ('신흥', 22),
#  ('검색', 22),
#  ('멀다', 22),
#  ('냄새', 22),
#  ('만족', 22),
#  ('맛없다', 22),
#  ('소품', 22),
#  ('기본', 22),
#  ('뭔가', 22),
#  ('가도', 22),
#  ('복숭아', 22),
#  ('달라', 22),
#  ('사실', 22),
#  ('에끌레어', 22),
#  ('아담하다', 21),
#  ('아름답다', 21),
#  ('친절', 21),
#  ('나누다', 21),
#  ('깔다', 21),
#  ('후기', 21),
#  ('스콘', 21),
#  ('카페인', 21),
#  ('열다', 21),
#  ('테이크아웃', 21),
#  ('진심', 21),
#  ('기억', 21),
#  ('더욱', 21),
#  ('가볍다', 21),
#  ('시티', 21),
#  ('식감', 21),
#  ('약간', 21),
#  ('바나나', 20),
#  ('통창', 20),
#  ('운영', 20),
#  ('개인', 20),
#  ('판매', 20),
#  ('그대로', 20),
#  ('얼다', 20),
#  ('플레이', 20),
#  ('니까', 20),
#  ('매일', 20),
#  ('담다', 20),
#  ('가야', 20),
#  ('잡다', 20),
#  ('동반', 20),
#  ('포토', 20),
#  ('따로', 20),
#  ('살다', 20),
#  ('예전', 20),
#  ('해주다', 20),
#  ('강하다', 20),
#  ('선택', 20),
#  ('순삭', 20),
#  ('시래기', 20),
#  ('팬케이크', 20),
#  ('튀르키예', 20),
#  ('트리', 19),
#  ('가을', 19),
#  ('올리다', 19),
#  ('너무나', 19),
#  ('머물다', 19),
#  ('나누기', 19),
#  ('정성', 19),
#  ('자기', 19),
#  ('사용', 19),
#  ('나들이', 19),
#  ('넉넉하다', 19),
#  ('긋다', 19),
#  ('듣다', 19),
#  ('덕분', 19),
#  ('감동', 19),
#  ('한번', 19),
#  ('수박', 19),
#  ('설명', 19),
#  ('저격', 18),
#  ('이상', 18),
#  ('다르다', 18),
#  ('이라서', 18),
#  ('촉촉하다', 18),
#  ('만에', 18),
#  ('신상', 18),
#  ('센스', 18),
#  ('무섭다', 18),
#  ('주차장', 18),
#  ('코스', 18),
#  ('단맛', 18),
#  ('스럽다', 18),
#  ('빈티', 18),
#  ('차도', 18),
#  ('평범하다', 18),
#  ('햇빛', 18),
#  ('사랑', 18),
#  ('안주', 18),
#  ('깊다', 18),
#  ('선물', 18),
#  ('포근하다', 18),
#  ('세트', 18),
#  ('뜨다', 18),
#  ('위험하다', 18),
#  ('프토', 18),
#  ('딸기모찌', 18),
#  ('화채', 18),
#  ('예정', 17),
#  ('버스', 17),
#  ('종종', 17),
#  ('식물', 17),
#  ('바삭', 17),
#  ('빠지다', 17),
#  ('산책', 17),
#  ('얼마', 17),
#  ('녹차', 17),
#  ('창문', 17),
#  ('한국', 17),
#  ('에어컨', 17),
#  ('담요', 17),
#  ('해도', 17),
#  ('거의', 17),
#  ('국적', 17),
#  ('경험', 17),
#  ('계시다', 17),
#  ('보다는', 17),
#  ('타다', 17),
#  ('도착', 17),
#  ('언덕', 17),
#  ('까눌레', 17),
#  ('빨리', 17),
#  ('바뀌다', 17),
#  ('조심하다', 17),
#  ('집중', 16),
#  ('토요일', 16),
#  ('가깝다', 16),
#  ('두다', 16),
#  ('매번', 16),
#  ('충분하다', 16),
#  ('힘드다', 16),
#  ('나중', 16),
#  ('날다', 16),
#  ('건물', 16),
#  ('심지어', 16),
#  ('뚜레쥬르', 16),
#  ('가끔', 16),
#  ('우리', 16),
#  ('선선', 16),
#  ('생일', 16),
#  ('하늘', 16),
#  ('이어서', 16),
#  ('데리', 16),
#  ('비다', 16),
#  ('때리다', 16),
#  ('빼다', 16),
#  ('색다르다', 16),
#  ('점심', 16),
#  ('과자', 16),
#  ('파다', 16),
#  ('제대로', 16),
#  ('어렵다', 16),
#  ('흑임자', 16),
#  ('이색', 16),
#  ('크루아상', 16),
#  ('아몬드', 16),
#  ('오리', 16),
#  ('젤라토', 16),
#  ('크레마', 16),
#  ('오래오래', 15),
#  ('저번', 15),
#  ('선곡', 15),
#  ('부분', 15),
#  ('타고', 15),
#  ('에서는', 15),
#  ('최근', 15),
#  ('모습', 15),
#  ('다니다', 15),
#  ('반하다', 15),
#  ('도리', 15),
#  ('들어서다', 15),
#  ('초록', 15),
#  ('끝내주다', 15),
#  ('아기', 15),
#  ('응대', 15),
#  ('브레드', 15),
#  ('보람', 15),
#  ('퀄리티', 15),
#  ('할인', 15),
#  ('오거리', 15),
#  ('식빵', 15),
#  ('곰돌이', 15),
#  ('브륄레', 15),
#  ('초콜릿', 15),
#  ('써다', 15),
#  ('가까이', 15),
#  ('걸다', 15),
#  ('외국인', 15),
#  ('나쁘다', 15),
#  ('크런치', 15),
#  ('그래서', 15),
#  ('일반', 15),
#  ('보틀', 15),
#  ('라는', 15),
#  ('대로', 15),
#  ('엽서', 15),
#  ('청결하다', 15),
#  ('사악하다', 15),
#  ('스탠', 15),
#  ('마지막', 14),
#  ('바쁘다', 14),
#  ('바라보다', 14),
#  ('도전', 14),
#  ('게다가', 14),
#  ('찰떡', 14),
#  ('물론', 14),
#  ('곳곳', 14),
#  ('대다', 14),
#  ('소문', 14),
#  ('주신', 14),
#  ('안쪽', 14),
#  ('오르다', 14),
#  ('오히려', 14),
#  ('평소', 14),
#  ('이르다', 14),
#  ('블로그', 14),
#  ('푸다', 14),
#  ('스무디', 14),
#  ('밉다', 14),
#  ('짱짱', 14),
#  ('듬뿍', 14),
#  ('중이', 14),
#  ('아인', 14),
#  ('슈페', 14),
#  ('만의', 14),
#  ('뜨겁다', 14),
#  ('먼지', 14),
#  ('배달', 14),
#  ('흐리다', 14),
#  ('고슴도치', 14),
#  ('배경', 14),
#  ('피스타치오', 14),
#  ('프사', 14),
#  ('데이즈', 14),
#  ('토터스', 14),
#  ('흑해', 14),
#  ('돌아다니다', 13),
#  ('숨다', 13),
#  ('숨기다', 13),
#  ('북적', 13),
#  ('이제', 13),
#  ('커서', 13),
#  ('건데', 13),
#  ('레모네이드', 13),
#  ('그렇게', 13),
#  ('무화과', 13),
#  ('붐비다', 13),
#  ('나요', 13),
#  ('지하', 13),
#  ('사이', 13),
#  ('한참', 13),
#  ('걱정', 13),
#  ('언제', 13),
#  ('불다', 13),
#  ('필수', 13),
#  ('에이', 13),
#  ('하이', 13),
#  ('아무', 13),
#  ('바꾸다', 13),
#  ('휴양지', 13),
#  ('오시', 13),
#  ('가루', 13),
#  ('시나몬', 13),
#  ('베이', 13),
#  ('대비', 13),
#  ('인정', 13),
#  ('훌륭하다', 13),
#  ('연하다', 13),
#  ('하니', 13),
#  ('전경', 13),
#  ('대충', 13),
#  ('클래식', 13),
#  ('분도', 13),
#  ('굽다', 13),
#  ('오믈렛', 13),
#  ('시즌', 13),
#  ('바텐더', 13),
#  ('당기다', 12),
#  ('럼블', 12),
#  ('잔잔하다', 12),
#  ('텐데', 12),
#  ('으로도', 12),
#  ('엄마', 12),
#  ('애정', 12),
#  ('우선', 12),
#  ('이라는', 12),
#  ('로운', 12),
#  ('찾아보다', 12),
#  ('믿다', 12),
#  ('벌써', 12),
#  ('겨울', 12),
#  ('신경', 12),
#  ('떨어지다', 12),
#  ('외부', 12),
#  ('많아지다', 12),
#  ('스카치', 12),
#  ('테바', 12),
#  ('배부르다', 12),
#  ('요기', 12),
#  ('시럽', 12),
#  ('아메', 12),
#  ('비슷하다', 12),
#  ('먼저', 12),
#  ('장난', 12),
#  ('예술', 12),
#  ('자세하다', 12),
#  ('탁트인', 12),
#  ('오전', 12),
#  ('안내', 12),
#  ('한눈', 12),
#  ('라니', 12),
#  ('필요하다', 12),
#  ('식혜', 12),
#  ('아직', 12),
#  ('니스', 12),
#  ('달콤하다', 12),
#  ('겉바', 12),
#  ('만나다', 12),
#  ('와도', 12),
#  ('세상', 12),
#  ('대신', 12),
#  ('지나다', 12),
#  ('사랑스럽다', 12),
#  ('이미', 12),
#  ('입장', 12),
#  ('금방', 12),
#  ('디자인', 12),
#  ('대가', 12),
#  ('품절', 12),
#  ('에그', 12),
#  ('시식', 12),
#  ('막도', 12),
#  ('영화', 12),
#  ('크림브륄레', 12),
#  ('토스티', 12),
#  ('푸플레', 12),
#  ('다소', 11),
#  ('애매하다', 11),
#  ('행복', 11),
#  ('합리', 11),
#  ('훨씬', 11),
#  ('환상', 11),
#  ('스럽지', 11),
#  ('마침', 11),
#  ('에서도', 11),
#  ('잠시', 11),
#  ('따르다', 11),
#  ('변경', 11),
#  ('오르막', 11),
#  ('포인트', 11),
#  ('바게트', 11),
#  ('작고', 11),
#  ('뚫리다', 11),
#  ('지금', 11),
#  ('곳도', 11),
#  ('연인', 11),
#  ('애견', 11),
#  ('수도', 11),
#  ('기도', 11),
#  ('맞추다', 11),
#  ('단점', 11),
#  ('보시', 11),
#  ('외관', 11),
#  ('바나나브레드', 11),
#  ('밝다', 11),
#  ('밀가루', 11),
#  ('준비', 11),
#  ('걸리다', 11),
#  ('협소하', 11),
#  ('차갑다', 11),
#  ('바치', 11),
#  ('블루베리', 11),
#  ('부담', 11),
#  ('그다지', 11),
#  ('길다', 11),
#  ('뽀뽀', 11),
#  ('댕댕', 11),
#  ('외국', 11),
#  ('소스', 11),
#  ('만석', 11),
#  ('인기', 11),
#  ('그런데', 11),
#  ('스럽게', 11),
#  ('자연', 11),
#  ('다방', 11),
#  ('빌라', 11),
#  ('오이', 11),
#  ('비도', 10),
#  ('돌다', 10),
#  ('싸다', 10),
#  ('잡고', 10),
#  ('여유롭다', 10),
#  ('시작', 10),
#  ('담백하다', 10),
#  ('은은하다', 10),
#  ('또한', 10),
#  ('카페라테', 10),
#  ('똑같다', 10),
#  ('창밖', 10),
#  ('아기자기', 10),
#  ('놀래다', 10),
#  ('무슨', 10),
#  ('남아', 10),
#  ('사라지다', 10),
#  ('뿌리다', 10),
#  ('사르다', 10),
#  ('콘텐츠', 10),
#  ('틀어주다', 10),
#  ('쫄깃', 10),
#  ('개방', 10),
#  ('엘피', 10),
#  ('위로', 10),
#  ('정보', 10),
#  ('라면', 10),
#  ('떨다', 10),
#  ('용산구', 10),
#  ('당황', 10),
#  ('부르다', 10),
#  ('이해', 10),
#  ('맑은', 10),
#  ('언니', 10),
#  ('먹음', 10),
#  ('말고', 10),
#  ('아지트', 10),
#  ('이지', 10),
#  ('옷장', 10),
#  ('동굴', 10),
#  ('조명', 10),
#  ('이서', 10),
#  ('핼러윈', 10),
#  ('다락방', 10),
#  ('별관', 10),
#  ('기다', 10),
#  ('간식', 10),
#  ('미세', 10),
#  ('챙기다', 10),
#  ('동안', 10),
#  ('모카', 10),
#  ('마치', 10),
#  ('채우다', 10),
#  ('셰프', 10),
#  ('상태', 10),
#  ('다행하다', 10),
#  ('결제', 10),
#  ('미리', 10),
#  ('한테', 10),
#  ('거기', 10),
#  ('달인', 10),
#  ('두부', 10),
#  ('대파', 10),
#  ('연말', 10),
#  ('핸드', 10),
#  ('앤티크', 10),
#  ('낭낭', 9),
#  ('더위', 9),
#  ('간격', 9),
#  ('대표', 9),
#  ('에만', 9),
#  ('이브', 9),
#  ('호두', 9),
#  ('교회', 9),
#  ('그리다', 9),
#  ('언덕길', 9),
#  ('감다', 9),
#  ('안이', 9),
#  ('이벤트', 9),
#  ('세다', 9),
#  ('홀린', 9),
#  ('길이', 9),
#  ('알바', 9),
#  ('그게', 9),
#  ('그저', 9),
#  ('깡패', 9),
#  ('후회', 9),
#  ('고요', 9),
#  ('지난번', 9),
#  ('이면', 9),
#  ('추워지다', 9),
#  ('석양', 9),
#  ('잊다', 9),
#  ('치다', 9),
#  ...]

# %% [markdown]
# - 불용어 좀 더 상의해서 제거해야할듯.
# - 일단은 러프하게 그냥 하자.

# %%
with open('/content/drive/MyDrive/멋쟁이사자차럼/data/stopwords.txt', 'r', encoding = 'CP949') as f:
    list_file = f.read()

# 불용어 리스트 생성
stopwords = list_file.split(",")  # 쉼표로 나누기

# 불용어 제거
remove_stopwords = [x for x in remove_one_word if x not in stopwords]
len(remove_stopwords)
# Out:
# 60499

# %%
Counter(remove_stopwords).most_common()
# Out:
# [('좋다', 4203),
#  ('맛있다', 3772),
#  ('커피', 1452),
#  ('카페', 1193),
#  ('먹다', 1189),
#  ('분위기', 1011),
#  ('친절하다', 969),
#  ('해방촌', 725),
#  ('맛집', 686),
#  ('디저트', 669),
#  ('사장', 643),
#  ('음료', 579),
#  ('예쁘다', 568),
#  ('방문', 490),
#  ('루프', 464),
#  ('케이크', 463),
#  ('자다', 458),
#  ('귀엽다', 366),
#  ('인테리어', 356),
#  ('많다', 351),
#  ('라테', 345),
#  ('이쁘다', 290),
#  ('자리', 265),
#  ('공간', 264),
#  ('아늑하다', 259),
#  ('최고', 256),
#  ('남산', 250),
#  ('추천', 245),
#  ('매장', 243),
#  ('사진', 224),
#  ('메뉴', 221),
#  ('사람', 220),
#  ('수플레', 219),
#  ('음식', 215),
#  ('직원', 215),
#  ('크림', 211),
#  ('친구', 206),
#  ('가격', 206),
#  ('조용하다', 189),
#  ('들어가다', 181),
#  ('크루', 180),
#  ('좋아하다', 176),
#  ('자주', 165),
#  ('가게', 163),
#  ('느낌', 162),
#  ('주문', 160),
#  ('생각', 158),
#  ('기분', 152),
#  ('아쉽다', 152),
#  ('멋지다', 150),
#  ('찾다', 148),
#  ('날씨', 148),
#  ('앉다', 144),
#  ('카이', 143),
#  ('처음', 141),
#  ('갈다', 131),
#  ('분들', 130),
#  ('말다', 129),
#  ('다양하다', 128),
#  ('비싸다', 128),
#  ('아주', 127),
#  ('계단', 125),
#  ('넓다', 124),
#  ('깔끔하다', 122),
#  ('쿠키', 122),
#  ('편하다', 121),
#  ('마시다', 120),
#  ('시원하다', 120),
#  ('만들다', 119),
#  ('따뜻하다', 116),
#  ('종류', 115),
#  ('즐기다', 114),
#  ('크다', 113),
#  ('아메리카노', 111),
#  ('초코', 110),
#  ('힐링', 109),
#  ('베이글', 107),
#  ('부드럽다', 105),
#  ('들어오다', 103),
#  ('밀크', 102),
#  ('테라스', 101),
#  ('올라가다', 100),
#  ('샌드위치', 100),
#  ('타워', 100),
#  ('들르다', 98),
#  ('야경', 98),
#  ('덥다', 95),
#  ('달달', 94),
#  ('내부', 94),
#  ('데이트', 94),
#  ('찍다', 94),
#  ('브런치', 94),
#  ('동네', 93),
#  ('에도', 93),
#  ('생기다', 93),
#  ('테이블', 92),
#  ('감성', 92),
#  ('보내다', 91),
#  ('거북이', 91),
#  ('강아지', 90),
#  ('노을', 90),
#  ('괜찮다', 90),
#  ('우연히', 88),
#  ('오픈', 88),
#  ('근처', 87),
#  ('대화', 86),
#  ('딸기', 86),
#  ('레몬', 82),
#  ('직접', 81),
#  ('존맛', 81),
#  ('주스', 81),
#  ('주말', 79),
#  ('음악', 79),
#  ('실내', 78),
#  ('푸딩', 78),
#  ('산도', 77),
#  ('감사하다', 76),
#  ('강추', 76),
#  ('가면', 76),
#  ('신흥시장', 75),
#  ('버터', 74),
#  ('고소하다', 73),
#  ('낭시', 72),
#  ('특별하다', 72),
#  ('굿굿', 72),
#  ('치즈케이크', 72),
#  ('비건', 72),
#  ('느껴지다', 71),
#  ('이용', 71),
#  ('터키', 71),
#  ('먹기', 70),
#  ('포장', 70),
#  ('평일', 69),
#  ('좌석', 69),
#  ('모찌', 69),
#  ('어울리다', 68),
#  ('아기자기하다', 67),
#  ('항상', 67),
#  ('빙수', 67),
#  ('치즈', 67),
#  ('가성', 65),
#  ('미치다', 65),
#  ('놀다', 64),
#  ('신선하다', 64),
#  ('요즘', 63),
#  ('편안하다', 63),
#  ('차다', 63),
#  ('빵집', 63),
#  ('기다리다', 62),
#  ('서울', 62),
#  ('좁다', 62),
#  ('발견', 61),
#  ('진하다', 61),
#  ('별로', 61),
#  ('야외', 61),
#  ('행복하다', 61),
#  ('무스', 61),
#  ('리뷰', 60),
#  ('아이스크림', 60),
#  ('털실', 60),
#  ('적당하다', 59),
#  ('장소', 59),
#  ('저녁', 59),
#  ('위치', 58),
#  ('말차', 58),
#  ('꾸꾸', 58),
#  ('저렴하다', 57),
#  ('화장실', 57),
#  ('한잔', 57),
#  ('기대', 56),
#  ('달다', 56),
#  ('주시', 56),
#  ('유명하다', 56),
#  ('독특하다', 56),
#  ('지나가다', 55),
#  ('새롭다', 55),
#  ('다녀오다', 55),
#  ('들리다', 54),
#  ('힘들다', 54),
#  ('소금', 54),
#  ('노래', 53),
#  ('토스트', 53),
#  ('찍기', 52),
#  ('느끼다', 52),
#  ('불편하다', 52),
#  ('오랜', 52),
#  ('과일', 51),
#  ('깨끗하다', 50),
#  ('상큼', 50),
#  ('바질', 50),
#  ('쉬다', 49),
#  ('대박', 49),
#  ('여기다', 49),
#  ('웨이', 49),
#  ('프렌치토스트', 49),
#  ('꾸다', 48),
#  ('서비스', 48),
#  ('에스프레소', 48),
#  ('아이스', 47),
#  ('이태원', 47),
#  ('보기', 47),
#  ('드리다', 46),
#  ('찌다', 46),
#  ('단골', 46),
#  ('작다', 46),
#  ('멋있다', 46),
#  ('손님', 46),
#  ('특이하다', 46),
#  ('신기하다', 45),
#  ('구경', 45),
#  ('건강하다', 45),
#  ('맛보다', 45),
#  ('늦다', 45),
#  ('고구마', 45),
#  ('가능하다', 44),
#  ('산미', 44),
#  ('지다', 44),
#  ('쓰다', 44),
#  ('재밌다', 44),
#  ('피자', 44),
#  ('옥상', 44),
#  ('여유', 43),
#  ('가기', 43),
#  ('일찍', 43),
#  ('인생', 43),
#  ('플레', 43),
#  ('무조건', 42),
#  ('경치', 42),
#  ('콘셉트', 42),
#  ('아침', 42),
#  ('취향', 41),
#  ('번째', 41),
#  ('비주', 41),
#  ('께서', 40),
#  ('쾌적하다', 40),
#  ('적다', 40),
#  ('창가', 40),
#  ('추가', 40),
#  ('드립', 40),
#  ('인스타', 39),
#  ('맞다', 39),
#  ('바닐라', 39),
#  ('찾아가다', 39),
#  ('쏘다', 39),
#  ('골목', 38),
#  ('즐겁다', 38),
#  ('예약', 38),
#  ('입맛', 37),
#  ('편이', 37),
#  ('맥주', 37),
#  ('오렌지', 37),
#  ('원두', 36),
#  ('드디어', 36),
#  ('레몬에이드', 36),
#  ('줄다', 36),
#  ('생각나다', 36),
#  ('용산', 36),
#  ('모양', 36),
#  ('풍경', 36),
#  ('입구', 36),
#  ('가세', 36),
#  ('메다', 36),
#  ('오후', 35),
#  ('남자', 35),
#  ('나서다', 35),
#  ('보이', 35),
#  ('토마토', 35),
#  ('트이다', 35),
#  ('무난', 35),
#  ('착즙', 35),
#  ('만족하다', 34),
#  ('웨이팅', 34),
#  ('추다', 34),
#  ('조합', 34),
#  ('우유', 34),
#  ('버리다', 34),
#  ('얼그레이', 34),
#  ('재료', 34),
#  ('짜다', 34),
#  ('편지', 34),
#  ('인상', 34),
#  ('꾸미다', 33),
#  ('춥다', 33),
#  ('시장', 33),
#  ('굉장하다', 33),
#  ('추하다', 33),
#  ('번창', 32),
#  ('타르트', 32),
#  ('찾아오다', 32),
#  ('식사', 32),
#  ('불친절하다', 32),
#  ('장님', 32),
#  ('눕다', 32),
#  ('파스타', 32),
#  ('다쿠아즈', 32),
#  ('전체', 31),
#  ('되게', 31),
#  ('남기다', 31),
#  ('주차', 31),
#  ('와인', 31),
#  ('페인', 30),
#  ('놓다', 30),
#  ('여름', 30),
#  ('매력', 30),
#  ('의사', 29),
#  ('이야기', 29),
#  ('읽다', 29),
#  ('디카', 29),
#  ('수제', 29),
#  ('올라오다', 29),
#  ('사다', 29),
#  ('자리다', 29),
#  ('이름', 29),
#  ('건지다', 29),
#  ('몽블랑', 29),
#  ('진동', 29),
#  ('소리', 28),
#  ('화이트', 28),
#  ('좋아지다', 28),
#  ('양도', 28),
#  ('궁금하다', 28),
#  ('아깝다', 28),
#  ('특색', 28),
#  ('거리', 28),
#  ('브라우니', 28),
#  ('착하다', 28),
#  ('따다', 28),
#  ('전망', 28),
#  ('오래', 28),
#  ('프리', 28),
#  ('가득하다', 28),
#  ('연어', 28),
#  ('테린느', 28),
#  ('오랑', 28),
#  ('크리스마스', 27),
#  ('만족스럽다', 27),
#  ('햇살', 27),
#  ('후암동', 27),
#  ('완벽하다', 27),
#  ('마음', 27),
#  ('여자', 27),
#  ('딱이다', 27),
#  ('그만큼', 27),
#  ('대기', 27),
#  ('우시', 27),
#  ('차분하다', 26),
#  ('한적하다', 26),
#  ('이유', 26),
#  ('얘기', 26),
#  ('고르다', 26),
#  ('나가다', 26),
#  ('쓸다', 26),
#  ('생크림', 26),
#  ('바람', 26),
#  ('지인', 26),
#  ('고급', 26),
#  ('바스크', 26),
#  ('파운드', 26),
#  ('타자기', 26),
#  ('보통', 25),
#  ('시끄럽다', 25),
#  ('추억', 25),
#  ('오기', 25),
#  ('기대하다', 25),
#  ('살짝', 25),
#  ('높다', 25),
#  ('얼음', 25),
#  ('인지', 25),
#  ('칵테일', 25),
#  ('가득', 25),
#  ('피클', 25),
#  ('의자', 24),
#  ('찾기', 24),
#  ('마시기', 24),
#  ('팔다', 24),
#  ('걷다', 24),
#  ('재미', 24),
#  ('후르', 24),
#  ('최애', 24),
#  ('넣다', 24),
#  ('글루텐', 24),
#  ('다포딜', 24),
#  ('고민', 23),
#  ('하루', 23),
#  ('아래', 23),
#  ('플랫', 23),
#  ('우드', 23),
#  ('쫀득', 23),
#  ('주변', 23),
#  ('구매', 23),
#  ('느끼하다', 23),
#  ('망고', 23),
#  ('샐러드', 23),
#  ('원하다', 23),
#  ('개다', 23),
#  ('여행', 23),
#  ('일몰', 23),
#  ('해방', 23),
#  ('감상', 23),
#  ('자몽', 23),
#  ('티라미수', 23),
#  ('녹다', 23),
#  ('치킨', 23),
#  ('작업', 22),
#  ('스타일', 22),
#  ('수다', 22),
#  ('신흥', 22),
#  ('검색', 22),
#  ('멀다', 22),
#  ('냄새', 22),
#  ('만족', 22),
#  ('맛없다', 22),
#  ('소품', 22),
#  ('기본', 22),
#  ('뭔가', 22),
#  ('가도', 22),
#  ('복숭아', 22),
#  ('달라', 22),
#  ('사실', 22),
#  ('에끌레어', 22),
#  ('아담하다', 21),
#  ('아름답다', 21),
#  ('친절', 21),
#  ('나누다', 21),
#  ('깔다', 21),
#  ('후기', 21),
#  ('스콘', 21),
#  ('카페인', 21),
#  ('열다', 21),
#  ('테이크아웃', 21),
#  ('진심', 21),
#  ('기억', 21),
#  ('더욱', 21),
#  ('가볍다', 21),
#  ('시티', 21),
#  ('식감', 21),
#  ('바나나', 20),
#  ('통창', 20),
#  ('운영', 20),
#  ('판매', 20),
#  ('그대로', 20),
#  ('얼다', 20),
#  ('플레이', 20),
#  ('니까', 20),
#  ('매일', 20),
#  ('가야', 20),
#  ('잡다', 20),
#  ('동반', 20),
#  ('포토', 20),
#  ('따로', 20),
#  ('살다', 20),
#  ('예전', 20),
#  ('해주다', 20),
#  ('강하다', 20),
#  ('선택', 20),
#  ('순삭', 20),
#  ('시래기', 20),
#  ('팬케이크', 20),
#  ('튀르키예', 20),
#  ('트리', 19),
#  ('가을', 19),
#  ('올리다', 19),
#  ('너무나', 19),
#  ('머물다', 19),
#  ('나누기', 19),
#  ('정성', 19),
#  ('사용', 19),
#  ('나들이', 19),
#  ('넉넉하다', 19),
#  ('긋다', 19),
#  ('듣다', 19),
#  ('덕분', 19),
#  ('감동', 19),
#  ('수박', 19),
#  ('설명', 19),
#  ('저격', 18),
#  ('다르다', 18),
#  ('이라서', 18),
#  ('촉촉하다', 18),
#  ('만에', 18),
#  ('신상', 18),
#  ('센스', 18),
#  ('무섭다', 18),
#  ('주차장', 18),
#  ('코스', 18),
#  ('단맛', 18),
#  ('빈티', 18),
#  ('차도', 18),
#  ('평범하다', 18),
#  ('햇빛', 18),
#  ('사랑', 18),
#  ('안주', 18),
#  ('깊다', 18),
#  ('선물', 18),
#  ('포근하다', 18),
#  ('세트', 18),
#  ('뜨다', 18),
#  ('위험하다', 18),
#  ('프토', 18),
#  ('딸기모찌', 18),
#  ('화채', 18),
#  ('예정', 17),
#  ('버스', 17),
#  ('종종', 17),
#  ('식물', 17),
#  ('바삭', 17),
#  ('빠지다', 17),
#  ('산책', 17),
#  ('녹차', 17),
#  ('창문', 17),
#  ('한국', 17),
#  ('에어컨', 17),
#  ('담요', 17),
#  ('해도', 17),
#  ('국적', 17),
#  ('경험', 17),
#  ('계시다', 17),
#  ('도착', 17),
#  ('언덕', 17),
#  ('까눌레', 17),
#  ('빨리', 17),
#  ('바뀌다', 17),
#  ('조심하다', 17),
#  ('집중', 16),
#  ('토요일', 16),
#  ('가깝다', 16),
#  ('충분하다', 16),
#  ('힘드다', 16),
#  ('나중', 16),
#  ('날다', 16),
#  ('건물', 16),
#  ('뚜레쥬르', 16),
#  ('가끔', 16),
#  ('선선', 16),
#  ('생일', 16),
#  ('하늘', 16),
#  ('데리', 16),
#  ('비다', 16),
#  ('때리다', 16),
#  ('빼다', 16),
#  ('색다르다', 16),
#  ('점심', 16),
#  ('과자', 16),
#  ('파다', 16),
#  ('어렵다', 16),
#  ('흑임자', 16),
#  ('이색', 16),
#  ('크루아상', 16),
#  ('아몬드', 16),
#  ('오리', 16),
#  ('젤라토', 16),
#  ('크레마', 16),
#  ('오래오래', 15),
#  ('저번', 15),
#  ('선곡', 15),
#  ('타고', 15),
#  ('에서는', 15),
#  ('최근', 15),
#  ('다니다', 15),
#  ('반하다', 15),
#  ('도리', 15),
#  ('들어서다', 15),
#  ('초록', 15),
#  ('끝내주다', 15),
#  ('아기', 15),
#  ('응대', 15),
#  ('브레드', 15),
#  ('보람', 15),
#  ('퀄리티', 15),
#  ('할인', 15),
#  ('오거리', 15),
#  ('식빵', 15),
#  ('곰돌이', 15),
#  ('브륄레', 15),
#  ('초콜릿', 15),
#  ('가까이', 15),
#  ('걸다', 15),
#  ('외국인', 15),
#  ('나쁘다', 15),
#  ('크런치', 15),
#  ('일반', 15),
#  ('보틀', 15),
#  ('엽서', 15),
#  ('청결하다', 15),
#  ('사악하다', 15),
#  ('스탠', 15),
#  ('마지막', 14),
#  ('바쁘다', 14),
#  ('바라보다', 14),
#  ('도전', 14),
#  ('찰떡', 14),
#  ('곳곳', 14),
#  ('소문', 14),
#  ('주신', 14),
#  ('안쪽', 14),
#  ('평소', 14),
#  ('이르다', 14),
#  ('블로그', 14),
#  ('푸다', 14),
#  ('스무디', 14),
#  ('밉다', 14),
#  ('짱짱', 14),
#  ('듬뿍', 14),
#  ('중이', 14),
#  ('아인', 14),
#  ('슈페', 14),
#  ('만의', 14),
#  ('뜨겁다', 14),
#  ('먼지', 14),
#  ('배달', 14),
#  ('흐리다', 14),
#  ('고슴도치', 14),
#  ('배경', 14),
#  ('피스타치오', 14),
#  ('프사', 14),
#  ('데이즈', 14),
#  ('토터스', 14),
#  ('흑해', 14),
#  ('돌아다니다', 13),
#  ('숨다', 13),
#  ('숨기다', 13),
#  ('북적', 13),
#  ('커서', 13),
#  ('건데', 13),
#  ('레모네이드', 13),
#  ('무화과', 13),
#  ('붐비다', 13),
#  ('나요', 13),
#  ('지하', 13),
#  ('사이', 13),
#  ('한참', 13),
#  ('걱정', 13),
#  ('불다', 13),
#  ('필수', 13),
#  ('에이', 13),
#  ('하이', 13),
#  ('아무', 13),
#  ('바꾸다', 13),
#  ('휴양지', 13),
#  ('오시', 13),
#  ('가루', 13),
#  ('시나몬', 13),
#  ('베이', 13),
#  ('대비', 13),
#  ('인정', 13),
#  ('훌륭하다', 13),
#  ('연하다', 13),
#  ('하니', 13),
#  ('전경', 13),
#  ('대충', 13),
#  ('클래식', 13),
#  ('분도', 13),
#  ('굽다', 13),
#  ('오믈렛', 13),
#  ('시즌', 13),
#  ('바텐더', 13),
#  ('당기다', 12),
#  ('럼블', 12),
#  ('잔잔하다', 12),
#  ('텐데', 12),
#  ('으로도', 12),
#  ('엄마', 12),
#  ('애정', 12),
#  ('로운', 12),
#  ('찾아보다', 12),
#  ('믿다', 12),
#  ('벌써', 12),
#  ('겨울', 12),
#  ('신경', 12),
#  ('떨어지다', 12),
#  ('외부', 12),
#  ('많아지다', 12),
#  ('스카치', 12),
#  ('테바', 12),
#  ('배부르다', 12),
#  ('요기', 12),
#  ('시럽', 12),
#  ('아메', 12),
#  ('먼저', 12),
#  ('장난', 12),
#  ('예술', 12),
#  ('자세하다', 12),
#  ('탁트인', 12),
#  ('오전', 12),
#  ('안내', 12),
#  ('한눈', 12),
#  ('필요하다', 12),
#  ('식혜', 12),
#  ('니스', 12),
#  ('달콤하다', 12),
#  ('겉바', 12),
#  ('만나다', 12),
#  ('와도', 12),
#  ('세상', 12),
#  ('대신', 12),
#  ('지나다', 12),
#  ('사랑스럽다', 12),
#  ('이미', 12),
#  ('입장', 12),
#  ('금방', 12),
#  ('디자인', 12),
#  ('대가', 12),
#  ('품절', 12),
#  ('에그', 12),
#  ('시식', 12),
#  ('막도', 12),
#  ('크림브륄레', 12),
#  ('토스티', 12),
#  ('푸플레', 12),
#  ('애매하다', 11),
#  ('행복', 11),
#  ('합리', 11),
#  ('환상', 11),
#  ('스럽지', 11),
#  ('마침', 11),
#  ('에서도', 11),
#  ('따르다', 11),
#  ('변경', 11),
#  ('오르막', 11),
#  ('포인트', 11),
#  ('바게트', 11),
#  ('작고', 11),
#  ('뚫리다', 11),
#  ('곳도', 11),
#  ('연인', 11),
#  ('애견', 11),
#  ('수도', 11),
#  ('기도', 11),
#  ('맞추다', 11),
#  ('단점', 11),
#  ('보시', 11),
#  ('외관', 11),
#  ('바나나브레드', 11),
#  ('밝다', 11),
#  ('밀가루', 11),
#  ('준비', 11),
#  ('걸리다', 11),
#  ('협소하', 11),
#  ('차갑다', 11),
#  ('바치', 11),
#  ('블루베리', 11),
#  ('부담', 11),
#  ('그다지', 11),
#  ('길다', 11),
#  ('뽀뽀', 11),
#  ('댕댕', 11),
#  ('외국', 11),
#  ('소스', 11),
#  ('만석', 11),
#  ('인기', 11),
#  ('스럽게', 11),
#  ('자연', 11),
#  ('다방', 11),
#  ('빌라', 11),
#  ('오이', 11),
#  ('비도', 10),
#  ('돌다', 10),
#  ('싸다', 10),
#  ('잡고', 10),
#  ('여유롭다', 10),
#  ('시작', 10),
#  ('담백하다', 10),
#  ('은은하다', 10),
#  ('카페라테', 10),
#  ('똑같다', 10),
#  ('창밖', 10),
#  ('아기자기', 10),
#  ('놀래다', 10),
#  ('남아', 10),
#  ('사라지다', 10),
#  ('뿌리다', 10),
#  ('사르다', 10),
#  ('콘텐츠', 10),
#  ('틀어주다', 10),
#  ('쫄깃', 10),
#  ('개방', 10),
#  ('엘피', 10),
#  ('위로', 10),
#  ('정보', 10),
#  ('라면', 10),
#  ('떨다', 10),
#  ('용산구', 10),
#  ('당황', 10),
#  ('부르다', 10),
#  ('이해', 10),
#  ('맑은', 10),
#  ('언니', 10),
#  ('먹음', 10),
#  ('아지트', 10),
#  ('이지', 10),
#  ('옷장', 10),
#  ('동굴', 10),
#  ('조명', 10),
#  ('이서', 10),
#  ('핼러윈', 10),
#  ('다락방', 10),
#  ('별관', 10),
#  ('기다', 10),
#  ('간식', 10),
#  ('미세', 10),
#  ('챙기다', 10),
#  ('모카', 10),
#  ('채우다', 10),
#  ('셰프', 10),
#  ('상태', 10),
#  ('다행하다', 10),
#  ('결제', 10),
#  ('미리', 10),
#  ('거기', 10),
#  ('달인', 10),
#  ('두부', 10),
#  ('대파', 10),
#  ('연말', 10),
#  ('핸드', 10),
#  ('앤티크', 10),
#  ('낭낭', 9),
#  ('더위', 9),
#  ('간격', 9),
#  ('대표', 9),
#  ('에만', 9),
#  ('이브', 9),
#  ('호두', 9),
#  ('교회', 9),
#  ('그리다', 9),
#  ('언덕길', 9),
#  ('감다', 9),
#  ('안이', 9),
#  ('이벤트', 9),
#  ('세다', 9),
#  ('홀린', 9),
#  ('길이', 9),
#  ('알바', 9),
#  ('그게', 9),
#  ('깡패', 9),
#  ('후회', 9),
#  ('고요', 9),
#  ('지난번', 9),
#  ('이면', 9),
#  ('추워지다', 9),
#  ('석양', 9),
#  ('잊다', 9),
#  ('치다', 9),
#  ('시내', 9),
#  ('빵빵', 9),
#  ('가능', 9),
#  ('당구', 9),
#  ('반려견', 9),
#  ('제공', 9),
#  ('스폿', 9),
#  ('장점', 9),
#  ('싫다', 9),
#  ('해지', 9),
#  ('확실하다', 9),
#  ('풀리다', 9),
#  ('시간대', 9),
#  ('와플', 9),
#  ('부산', 9),
#  ('싫어하다', 9),
#  ('구성', 9),
#  ('일본', 9),
#  ('베이커리', 9),
#  ('촉촉', 9),
#  ('중간', 9),
#  ('흔하다', 9),
#  ('언제나', 9),
#  ('서다', 9),
#  ('단호박', 9),
#  ('상당하다', 9),
#  ('유자', 9),
#  ('카드', 9),
#  ('초입', 9),
#  ('순하다', 9),
#  ('여전하다', 9),
#  ('가파르', 9),
#  ('협소', 9),
#  ('제한', 9),
#  ('내려가다', 9),
#  ('마들렌', 9),
#  ('알바생', 9),
#  ('라즈베리', 9),
#  ('라임', 9),
#  ('두불렛', 9),
#  ('에쏘', 9),
#  ('리필', 9),
#  ('밤수플레', 9),
#  ('초코바나나', 8),
#  ('정성스럽다', 8),
#  ('머무르다', 8),
#  ('수가', 8),
#  ('넘어가다', 8),
#  ('프로', 8),
#  ('젊다', 8),
#  ('감탄', 8),
#  ('차로', 8),
#  ('바깥', 8),
#  ('치고', 8),
#  ('맑다', 8),
#  ('바라다', 8),
#  ('도란도란', 8),
#  ('아주아주', 8),
#  ('가점', 8),
#  ('고급스럽다', 8),
#  ('해주시', 8),
#  ('공영', 8),
#  ('취저', 8),
#  ('뻔하다', 8),
#  ('커피집', 8),
#  ('물어보다', 8),
#  ('필요', 8),
#  ('꿀맛', 8),
#  ('유리', 8),
#  ('천국', 8),
#  ('주인', 8),
#  ('잡채', 8),
#  ('모로', 8),
#  ('청결', 8),
#  ('막히다', 8),
#  ('절대', 8),
#  ('아쉬움', 8),
#  ('데우다', 8),
#  ('페스', 8),
#  ('충전', 8),
#  ('아트', 8),
#  ('위층', 8),
#  ('미숫가루', 8),
#  ('운치', 8),
#  ('음료수', 8),
#  ('아이스티', 8),
#  ('진해', 8),
#  ('라이딩', 8),
#  ('분위', 8),
#  ('패션', 8),
#  ('터지다', 8),
#  ('작년', 8),
#  ('빠르다', 8),
#  ('가시', 8),
#  ('달빛', 8),
#  ('흘러가다', 8),
#  ('메뉴판', 8),
#  ('유니크', 8),
#  ('인사', 8),
#  ('컵케이크', 8),
#  ('위스키', 8),
#  ('반기다', 8),
#  ('비추다', 8),
#  ('불친절', 8),
#  ('견과류', 8),
#  ('조각', 8),
#  ('기준', 8),
#  ('만끽', 8),
#  ('워낙', 8),
#  ('가팔른', 8),
#  ('개맛', 8),
#  ('오트밀', 8),
#  ('블랙', 8),
#  ('씹히다', 8),
#  ('홍차', 8),
#  ('그림', 8),
#  ('명란', 8),
#  ('감자', 8),
#  ('쫀득하', 8),
#  ('시대', 8),
#  ('가리다', 8),
#  ('쉘터', 8),
#  ('필터', 8),
#  ('다포딜라테', 8),
#  ('다가', 7),
#  ('아웃', 7),
#  ('네이버', 7),
#  ('청포도', 7),
#  ('스트레스', 7),
#  ('어우러지다', 7),
#  ('채광', 7),
#  ('조화', 7),
#  ('실제', 7),
#  ('붙다', 7),
#  ('열심히', 7),
#  ('전반', 7),
#  ('미니', 7),
#  ('일부러', 7),
#  ('거나', 7),
#  ('에선', 7),
#  ('듯이', 7),
#  ('당일', 7),
#  ('궁합', 7),
#  ('애용', 7),
#  ('야채', 7),
#  ('겁나다', 7),
#  ('리얼', 7),
#  ('조만간', 7),
#  ('얼른', 7),
#  ('쌀쌀하다', 7),
#  ('기념', 7),
#  ('핫플', 7),
#  ('제로', 7),
#  ('끌리다', 7),
#  ('베리', 7),
#  ('대형', 7),
#  ('솔솔', 7),
#  ('포켓볼', 7),
#  ...]

# %% [markdown]
# - 빈도수 적은 단어들 보기

# %%
for item, count in Counter(remove_stopwords).most_common():
    if count==1:
        print(item)
# Out:
# 리스
# 행운
# 안정감
# 마일
# 드하
# 오래전
# 벼루
# 앤북앤
# 필름
# 비스킷
# 테이
# 시끌시끌하다
# 다저트
# 흡족하다
# 꾸역꾸역
# 우디
# 구원
# 카패
# 내미다
# 플루트
# 그램
# 겉바속쫀
# 잃어버리다
# 라디오
# 나시
# 타트
# 휘낭세
# 쏟아지다
# 순백
# 책방
# 코스터
# 쫀낭시에
# 늦잠
# 자고
# 쇼핑몰
# 세미나
# 차라
# 손해
# 계열
# 적재적소
# 초르르
# 가구
# 마주
# 과자류
# 푸릇
# 입지
# 신규
# 테이크
# 수운
# 도중
# 삼초
# 직장인
# 파격
# 곳임
# 빗방울
# 마루
# 에게도
# 식히다
# 시달리다
# 타지
# 취미
# 아티스트
# 괜스레
# 외식
# 축복
# 밤바람
# 마침표
# 혜택
# 항목
# 견줄
# 로우
# 레코드
# 턴테이블
# 청음
# 갑작스레
# 빌리다
# 과제
# 사근사근하다
# 사운드
# 한층
# 신선
# 올드
# 덕덕구스
# 심심하다
# 내기
# 오버
# 비행기
# 블라인드
# 음주
# 썸네일
# 경차
# 시원시원하다
# 빠작하
# 일욜
# 후끈하다
# 초대형
# 불꽃놀이
# 열악하다
# 접다
# 숙이다
# 구치소
# 철창
# 할머니
# 밥상
# 견주들
# 소개팅
# 종일
# 타운
# 숭실고
# 요거트
# 통틀어
# 아른거리다
# 진솔하다
# 쌩맥
# 이마트
# 붉다
# 물들다
# 간맥
# 비프
# 퍼먹는
# 주간
# 불고기
# 볗로입니
# 페퍼로니
# 볼률
# 조정
# 놀이터
# 하늘색
# 바라보이다
# 명동
# 익스트림
# 복잡복잡
# 생맥주
# 날리다
# 부서지다
# 엘리베이터
# 긴가민가하다
# 멀티
# 벚꽃
# 뒹굴거릴
# 마땅찮다
# 쿠션
# 쌀쌀
# 난방
# 홍대
# 팟카파오므쌉
# 피나콜라다
# 취합니
# 치앙마이
# 탱글탱글
# 면은
# 꼬릿파오무쌉
# 다져지다
# 양념
# 해외
# 모반
# 월길
# 얌커무양
# 말리부
# 파인애플
# 복판
# 우이
# 태원
# 와글와글
# 하하호호
# 찰깍
# 뿌팟퐁
# 커리
# 퓨전
# 푸팟퐁
# 아시안
# 항정살
# 구이
# 차만
# 입술
# 착색
# 만큼은
# 크래커
# 어린이날
# 허다
# 똠얌
# 파라다이스
# 카리브해
# 모히또
# 짜조
# 화이트와인
# 홀려
# 드감
# 마심
# 단술
# 말로
# 짱짱맨
# 탄자니아
# 활짝
# 단물
# 교양
# 쌓다
# 느긋하다
# 약제
# 생김새
# 갈라
# 키위
# 윙스
# 헬초코
# 이를
# 피로
# 파리
# 임보
# 연락
# 굿잡
# 공수
# 토모
# 찌롤
# 늘어지다
# 커퓌
# 임명
# 속세
# 훈훈하다
# 노원
# 강동
# 땡큐
# 둘째
# 서럽다
# 기운
# 우리나라
# 최곤
# 녹찻물
# 이냐
# 뽀짝
# 꾸덕스
# 친화력
# 부럽다
# 축하
# 강강추
# 큐트
# 사무실
# 어랏
# 멜번
# 금손이셔
# 덩이
# 코리
# 백이십
# 뭉치다
# 필리핀
# 녹아내리다
# 귀염뽀짝
# 긍정
# 얻다
# 왕강추
# 유제품
# 큐키
# 문구
# 더부룩하다
# 대추야자
# 박해
# 삐약이
# 뀰잼
# 장문
# 하얗다
# 구멍
# 뻘쭘했어
# 놨다
# 핵맛
# 쓱싹대다
# 잔뚝
# 다쿠
# 아이즈
# 신기
# 방기
# 빼먹다
# 눌려
# 맹물
# 송이
# 소박하다
# 생포
# 산뜻
# 신관
# 나누어지다
# 앙시
# 테스트
# 라며
# 땡볕
# 쾌쾌
# 부리고
# 지극히
# 어머
# 그네
# 텐트
# 외곽
# 궁전
# 캐러멜마키아토
# 오우
# 놔두다
# 등산
# 홀딱
# 반한
# 제리
# 쥼맛탱
# 순환
# 건너편
# 사지
# 붓다
# 전보
# 끝끝
# 박주
# 그녀
# 샷추
# 몰티저스
# 곤쥬님
# 빛나다
# 불행하다
# 해물
# 뒤쪽
# 환하다
# 시중
# 초코우유
# 활용
# 비품
# 램프
# 안타깝다
# 분주하다
# 맘때
# 고서
# 화초
# 꽃들이
# 음로
# 씻다
# 확보
# 연한
# 라벨
# 지로
# 방석
# 제주도
# 팝송
# 책고
# 끌다
# 텁텁
# 쓸데없다
# 벌컥벌컥
# 비치다
# 노밀바치케집
# 카공
# 주위
# 맛슐랭
# 인정받다
# 시일
# 상해
# 쩍쩍
# 푸석거리다
# 지은
# 진작
# 짐빔
# 우정
# 부여
# 우편함
# 기쁘다
# 비용
# 왁스
# 지정
# 활동
# 경복궁
# 크림샌드빵
# 크라상
# 따스
# 왁싱
# 우왕
# 침절해
# 허벅지
# 편지지
# 체인점
# 널담
# 국제우편
# 크리
# 간간이
# 발송
# 인가요
# 신기다
# 도라방스
# 쓰기
# 오름
# 쌩쌩하다
# 깜깜
# 지린다
# 익숙해지다
# 줄줄이
# 안절부절
# 스근하
# 심심
# 얌전하다
# 쉽다
# 둘러보기
# 가보
# 업체
# 순딩
# 적하
# 생전
# 안기다
# 이일
# 라고는
# 동동
# 야운
# 우주
# 달랑
# 철저하다
# 돌돌
# 짓다
# 오감
# 시무룩하다
# 진대
# 바글
# 천사
# 졸귀탱
# 흐뭇하다
# 낮밤
# 야간
# 프라페
# 카노
# 오진
# 쿠쿠
# 작가
# 무지무지
# 사심
# 하이라이트
# 왜인
# 억울하다
# 뮤비
# 또래
# 눈썹
# 보더
# 쪼르르
# 겸비
# 안녕
# 사소하다
# 멈무
# 곰샷
# 짖다
# 애교
# 부재
# 뛰어오다
# 커페
# 어어
# 여우
# 특별
# 앞뒤
# 브랙
# 외로
# 다지다
# 이주
# 취식
# 로즈마리
# 낭비하다
# 중심지
# 극치
# 반견견
# 뷰뷰
# 포토스폿
# 너머
# 졸맛
# 슐랭
# 뷰러
# 중국인
# 렌틸
# 탄탄하다
# 든지
# 신의
# 수인
# 차별
# 쌩쌩
# 노리다
# 알짝
# 조마조마하다
# 라테아트
# 넘어지다
# 굿국
# 싸구려
# 슬슬
# 휴지
# 여종
# 누굴
# 뿌옇다
# 보리차
# 감고
# 견디다
# 퀄리
# 티나
# 법칙
# 신비롭다
# 통로
# 움직
# 단백
# 길가
# 사수
# 비키다
# 버겁다
# 택할
# 무례하다
# 이해도
# 창렬
# 잔당
# 철로
# 듣기
# 외국어
# 후므스
# 카레
# 서향
# 하머스
# 새다
# 참조
# 덩어리
# 진토닉
# 짱쨍
# 파이다
# 패퍼
# 한적
# 다예
# 다락
# 비츄
# 삼삼하다
# 위태
# 레이
# 안전
# 장치
# 밤하늘
# 허름
# 신중하다
# 발랄하다
# 명도
# 대로의
# 샹그리
# 식초
# 카모마일
# 래서
# 구두
# 신고
# 탑재
# 불가
# 에서의
# 재활용
# 메탈
# 스트로
# 스타일리시
# 시들다
# 신선도
# 관대하다
# 광도
# 도자기
# 식기
# 델리
# 마이크
# 릭루빈
# 여유쁨
# 헥헥거리
# 인연
# 오잉
# 부터는
# 라이브
# 화려하다
# 다채롭
# 결혼기념일
# 드라마
# 문어
# 아란치니
# 샴페인
# 삼키다
# 입도
# 루콜라
# 퍼플
# 컬러
# 몽환
# 베르사체
# 리블
# 라쟈
# 몬드리안
# 부띠
# 뇨끼
# 쫀득쫀득하
# 모조리
# 바짝
# 헥헥
# 짙다
# 만족도
# 돌아서다
# 평화로움
# 친정
# 알밤
# 코인
# 세탁소
# 세탁기
# 스타
# 루메코
# 진지하다
# 허름한데
# 깜빡
# 마끼아또
# 와의
# 겉모습
# 판단
# 협소했
# 토피
# 운동복
# 하층
# 후딱
# 샹들리
# 뽀작
# 추측
# 몽실몽실
# 이클레어
# 타협
# 맛일
# 사르륵
# 행방
# 일전
# 트러스
# 바노피
# 누리
# 모자
# 커런트
# 퓌레
# 뚝딱
# 작품
# 퍼펙트
# 필링
# 손길
# 까지야
# 저걸
# 통째
# 초콜
# 현미
# 마가
# 으로서는
# 르몽플랑
# 사로자다
# 넘기다
# 크리스마스이브
# 망치다
# 흐음
# 내놓다
# 구해
# 도저히
# 쁘띠
# 뿌시기
# 취민데
# 불호
# 키마
# 블랑
# 앙증맞다
# 꼽히다
# 전시
# 디테일
# 던데
# 타이밍
# 모처럼
# 어케
# 최대
# 분점
# 픽해
# 스케일
# 유목민
# 존경
# 루트
# 봄바람
# 카운트
# 때우다
# 공예
# 전쟁
# 거임
# 먹킷
# 그만
# 니팅
# 니트로
# 드라이
# 프로그램
# 아이싱
# 배기
# 단가
# 셔츠
# 강남
# 개수
# 급경사
# 별실
# 강력하다
# 큰소리
# 뱃속
# 뒷맛
# 향기롭다
# 쫀쫀했어
# 끌레
# 럽럽입니
# 캐다
# 장인정신
# 파티스리
# 홀리
# 흐트러짐
# 오른쪽
# 주섬주섬
# 밀푀유
# 방서
# 리본
# 어캐
# 쿠기
# 꽁꽁
# 삭막하다
# 무너지다
# 휴무
# 전철역
# 살피다
# 예측
# 원가
# 사도
# 노맛
# 에끌레
# 방직
# 히스토리
# 파티쉐
# 분과
# 만요
# 만하
# 반점
# 이외
# 상쾌하다
# 동일하다
# 자가용
# 만족감
# 주소
# 주소지
# 주창
# 반절
# 독파
# 예술가
# 깃국
# 통실
# 알차다
# 속도
# 한식
# 접목
# 하프
# 살찌다
# 두툼
# 리언
# 헤비
# 죄다
# 저만큼
# 부끄러움
# 투명
# 핸드폰
# 끼우다
# 득득
# 토토
# 목록
# 연도
# 분발
# 장마
# 옹심이
# 끼니
# 라인업
# 달러
# 깨우다
# 양식
# 정겹다
# 연속
# 일간
# 목끝
# 차오르다
# 먹어주다
# 창의
# 런던
# 지엄
# 운전
# 김포
# 공항
# 가르다
# 컨디션
# 조일
# 아우라
# 얌전
# 포에버
# 피아노
# 이미지
# 파크
# 오물
# 큼지막하다
# 그라탕
# 닭고기
# 마리네
# 간도
# 골든타임
# 익히다
# 쫄깃해
# 채소
# 당귀
# 손맛
# 킬로
# 브런
# 감칠맛
# 질린다
# 초기
# 화해
# 말랑쫄깃
# 기지
# 후추
# 상의
# 흰둥이
# 멈머
# 르뱅
# 알고리즘
# 쫀쫀했고
# 슬쩍
# 유난히
# 점별
# 편차
# 밤밤
# 피곤하다
# 지근
# 서지
# 소보
# 조이
# 화장품
# 매가
# 오곡
# 굿굿굿굿
# 두둥
# 버튼
# 여신
# 체당
# 이리저리
# 사교성
# 티즁
# 마시멜로
# 무드라
# 오브
# 널리
# 널린
# 소름
# 끼치다
# 미아
# 추로스
# 츄러스
# 천재
# 택배
# 구경만
# 뒤집어지다
# 백천
# 너츠
# 초초
# 헤헷
# 부족함
# 눈팅
# 득템
# 베이킷
# 빠작빠작
# 주일
# 클라우드
# 시점
# 거고
# 판이
# 흔들리다
# 개선
# 느긋
# 대가리
# 아우
# 효효
# 바펍입니
# 지리다
# 입안
# 넘사벽
# 산토리
# 평온하다
# 치열
# 자누
# 탁탁
# 교육
# 시급하다
# 카펜데
# 미트파이
# 소나기
# 아무래도
# 지하철역
# 러브
# 버그
# 쉐키
# 시겅
# 순둥
# 대장
# 대부도
# 펼쳐지다
# 늠름하다
# 검다
# 시바
# 뷰맛
# 드류
# 초코쿠키
# 태위
# 태해
# 차르
# 모던
# 미숙
# 메롱
# 자꾸자꾸
# 야무지다
# 감격
# 얼리다
# 자가
# 유지
# 달리다
# 잡곡
# 토르티야
# 누룽지
# 찹쌀
# 명인
# 즐비하다
# 올리브
# 치아바타
# 휴일
# 탈콤
# 못지않다
# 염색
# 아들
# 대놓고
# 이딴
# 그따위
# 초등
# 규매
# 주도
# 공룡
# 유플러스
# 할라페뇨
# 맵다
# 큼직큼직하다
# 부합
# 바늘
# 슈톨렌
# 왤다
# 시몬
# 독감
# 미각
# 겠다
# 지르다
# 브레이드
# 매달
# 치키다
# 쉐프
# 주리다
# 업다
# 며칠
# 성격
# 공갈빵
# 리코
# 근래
# 때깔
# 한결
# 허기
# 달래다
# 어쩐
# 일로
# 책임지다
# 빵굼터
# 부친
# 심부름
# 신제품
# 러스크
# 털다
# 해뱅촌
# 쌘드위치
# 명장
# 그땐
# 품줠
# 방금
# 집사
# 쪽빵
# 주관
# 치고는
# 시오
# 첵오
# 어플
# 사라다
# 아삭아삭
# 쪽파
# 단종
# 천연
# 호빵
# 노노
# 지고
# 성분
# 제휴
# 실력
# 밤빵
# 가디
# 따라오다
# 수리
# 추강
# 빵순
# 이요
# 현금
# 이니까
# 비닐봉지
# 예민하다
# 찝찝하다
# 용이하다
# 업데이트
# 오른
# 철골
# 온도
# 답답
# 선정
# 시경
# 겹겹이
# 종이컵
# 갈남
# 건네다
# 사륵
# 설산
# 저당
# 경리
# 쭈욱
# 패스
# 사약
# 미지근하다
# 보완
# 삼박자
# 장단점
# 선명하다
# 부숴
# 띤띤
# 당첨
# 국물
# 버번
# 아이템
# 아사히
# 용품
# 진천
# 뷰어랜
# 회용
# 머그잔
# 송진아
# 환대
# 지옥
# 세차
# 도우
# 하염없이
# 짠하다
# 가슴속
# 이라기
# 은신
# 장관
# 손가락
# 그린티
# 진입
# 난이도
# 캡슐
# 욕구
# 초코파이
# 군침
# 고이
# 프리가
# 내용물
# 신해
# 펌킨
# 라벤더
# 지속
# 지향
# 가치관
# 싸이월드
# 시절
# 힐튼
# 수량
# 탄수
# 안심
# 레스토랑
# 중상
# 조개
# 잡음
# 대응
# 반영
# 리소토
# 가늠
# 상황
# 값어치
# 가량
# 문의
# 정시
# 오라
# 태블릿
# 조우
# 예약금
# 제약
# 날임
# 파노라마
# 골고루
# 소고기
# 구름
# 퍽퍽해
# 자세
# 진상
# 대하
# 하라
# 태도
# 엉망
# 전날
# 배정
# 열두
# 오심
# 허탕
# 마티니
# 저녁때
# 어두우
# 화사하다
# 목표
# 달성
# 쓸데없이
# 어스름
# 전향
# 유도
# 확장
# 메추리
# 인류
# 에겐
# 개개인
# 통모
# 지라
# 남대문
# 더움
# 탑임
# 무관심하다
# 뚜껑
# 팔천
# 트럭
# 돈가스
# 당면
# 초가
# 완제
# 레인지
# 마찬가지
# 수저
# 지리
# 간지나다
# 종이
# 휴대폰
# 돼지
# 이어진
# 팔리다
# 오한
# 레이스
# 대게
# 그러하다
# 또마
# 지저분하다
# 백신
# 브라
# 무자
# 근무
# 타투
# 싸가지
# 마산
# 지브리
# 쨍해
# 괴롭다
# 만드
# 여주시
# 베풀다
# 스크램블
# 격상
# 반입
# 금지
# 청담
# 술값
# 센치
# 땅땅
# 지지다
# 게이
# 정엽
# 브리
# 야물다
# 개또마
# 콘치
# 더락
# 라라
# 화하다
# 빠져나오다
# 접객
# 무채색
# 그레이
# 거닐다
# 테리
# 이태
# 첫째
# 타이거
# 절하
# 외한
# 상가
# 렵니
# 블렌드
# 연속성
# 아이컨택
# 그중
# 독특
# 어요
# 편도
# 카테고리
# 겉옷
# 분기
# 그랬더니
# 머신
# 말함
# 린다
# 회식
# 귯귯귯귯
# 주식
# 꼬박
# 디귿
# 타입
# 커버
# 사방
# 일광욕
# 알아차리다
# 시나몬롤
# 도가니
# 회색
# 스테인리스
# 오리진
# 픽할
# 원형
# 안정
# 삼성
# 아내
# 일요
# 추출
# 궁둥이
# 박하다
# 마챠
# 강렬하다
# 하마
# 성장
# 구복
# 만두
# 직전
# 허리
# 구부리다
# 스킬
# 아메리카
# 스모키
# 관계
# 나선형
# 카르
# 타도
# 쫀쫀해
# 기존
# 심오하다
# 명상
# 여진
# 엘살바도르
# 놈브레
# 디오스
# 두리
# 심야
# 입가심
# 영롱하다
# 조르바
# 대한민국
# 조물
# 한결같다
# 고가
# 옛스럽다
# 로럴
# 매료
# 간접
# 아포
# 감수
# 공중
# 집임
# 가파르다
# 전선
# 온화하다
# 덕지덕지
# 부디
# 주기
# 하우스
# 분홍
# 반지
# 헛디디다
# 너무도
# 선도주자
# 슈퍼스타
# 영광
# 현장
# 원샷
# 타이타닉
# 디카프리오
# 복작복작
# 한자리
# 버벅거리
# 보이시
# 분만
# 캐리어
# 쾌적
# 정해
# 민망하다
# 썸머
# 명령
# 눈빛
# 교환
# 공유
# 망하다
# 백만
# 아래층
# 불가하다
# 높이다
# 뽀짝이들
# 헤헿
# 별다르다
# 꺄악
# 지상
# 낙원
# 길어지다
# 쨩쨩맨
# 취준하
# 취뽀
# 썸녀
# 동년배
# 화원
# 맑음
# 왠지
# 월차
# 의향
# 몽몽이
# 자부
# 쫘악
# 업업
# 어딜
# 직하다
# 업뎃했어
# 층층
# 둘러싸다
# 걸어오다
# 그릭
# 썬셑
# 식수
# 쇼쇽
# 손흥민
# 선수
# 닮다
# 내셔널
# 지오
# 그래픽
# 스파
# 카리나
# 지젤
# 요카이
# 평해
# 상함
# 불만족
# 꼬숩
# 이구나
# 환기
# 갑작스럽다
# 화상
# 회의
# 참여
# 배신
# 도도
# 충분
# 펄펙
# 핵존맛
# 식다
# 라이프
# 체공
# 해질녁
# 박다
# 사이드
# 반샷
# 라가
# 념냠
# 상임
# 씌우다
# 죽여주다
# 쇼디치
# 버세
# 특징
# 힘내다
# 폭염
# 뚫다
# 칭찬
# 업그레이드
# 홀더
# 커피잔
# 트톱
# 로고
# 정수리
# 굿잡맨
# 존임
# 스쿱
# 어떡하다
# 파란
# 호떡
# 개미
# 이보
# 힙할
# 위엔
# 우프
# 글렛
# 용다
# 비우다
# 띵맛
# 분리
# 화요일
# 바싹
# 하겐다즈
# 고다
# 플하
# 푸프탑
# 비슷
# 전형
# 미니멀리즘
# 트렌디
# 트탑
# 적임
# 죽음
# 줄기
# 갤러리
# 통차
# 벼르
# 벼르던
# 두운
# 어머어머
# 연령
# 이프
# 탈진
# 가라앉다
# 플래시
# 빗다
# 입자
# 루이
# 보스
# 수선
# 쫀득함
# 넷이
# 텍스처
# 백차
# 처리
# 기계
# 톡특
# 젊음
# 거미줄
# 깜놀
# 철관음
# 다과
# 테린
# 어도
# 인도
# 고개
# 출입문
# 지네
# 부끄럽다
# 그만두다
# 보리
# 장흥
# 그릇
# 괜히
# 인디언
# 밀웜
# 티그레
# 굿규
# 투하
# 다식
# 보온병
# 식지
# 티팟
# 기반
# 오랜지
# 김밥
# 기장
# 알리오
# 리오
# 특선
# 루돌프
# 딸케
# 포동포동
# 청량감
# 자부심
# 해비
# 카펜
# 감산
# 턱별
# 대리석
# 세지
# 이탈리아
# 실컷
# 곤란하다
# 레이즌
# 신세계
# 흔쾌하다
# 환경
# 소도시
# 이불
# 불어오다
# 다포딜라페
# 크렘브뤨레
# 호일
# 뺏다
# 비누
# 이맘때
# 베프들
# 맘껏
# 뷔렐레
# 커팅
# 유무
# 킬링
# 크림브뢸레
# 있다뇨
# 고요하다
# 산다
# 포딜
# 연결하다
# 쪽쪽
# 사색
# 수선화
# 브륄
# 과테말라
# 이시고
# 온전
# 탑뷰
# 하필
# 진실
# 브뤨레
# 오트유
# 호로록
# 삼고
# 따갑다
# 단정하다
# 와우
# 쥬르츠
# 아랫
# 월욜
# 의하다
# 노크
# 덜컥
# 환성
# 초심
# 짱하다
# 입성
# 아무렇다
# 마키아토
# 달라지다
# 노리
# 반대
# 묻히다
# 커지다
# 실시간
# 노캔
# 포스트
# 또는
# 콜라주
# 살아나다
# 전화
# 엮어
# 피크
# 한몫
# 럭키걸
# 잠기
# 낫다
# 비롯
# 품다
# 재즈
# 쌓이다
# 스며들다
# 체고
# 부탁
# 팬지
# 꽃향
# 기억나다
# 내다보다
# 달고나
# 살짝궁
# 별거
# 커다랗다
# 에드
# 헤매다
# 가방
# 집어넣다
# 코코아
# 줄줄
# 무턱
# 대고
# 반기
# 공책
# 들여다보다
# 돌아보다
# 글자
# 출입구
# 답변
# 채운
# 처러
# 부도
# 촌스럽다
# 즉사
# 촤악
# 탁월하다
# 파랗다
# 충무로
# 사진전
# 광경
# 먹고다
# 해오다
# 노닐다
# 충만
# 부가
# 한여름
# 범벅
# 새록새록
# 불러일으키다
# 다녀가다
# 성은
# 놓이다
# 어깨
# 세기말
# 후반
# 개갑
# 인터넷
# 던지다
# 두기
# 라파
# 콘판
# 모닝커피
# 최고급
# 이신가
# 찍어내다
# 점심때
# 가동
# 여고생
# 동아리
# 스트라파짜토
# 카카오
# 쌉쌀하다
# 아란
# 치아
# 라나
# 회원
# 어느새다
# 분야
# 기원
# 이집
# 거푸
# 심장
# 콩닥콩닥
# 요런
# 라이더
# 거치
# 연장
# 강추추
# 콘판나
# 커른
# 양성
# 글쎄요
# 한남
# 복귀
# 맛나
# 콘파
# 진짬
# 꼰빠
# 편견
# 옴굿
# 저렇게
# 용량
# 잊혔습니
# 스트라바짜또
# 전문가
# 프렌치
# 아마도
# 치질
# 두근두근
# 축축하다
# 맞닥뜨
# 덩달아
# 먹방
# 무치다
# 낮술
# 나이트
# 프토네
# 공략
# 문자
# 아주머니
# 아저씨
# 쓰러지다
# 스파이크
# 이즈
# 강의
# 마구
# 계란찜
# 직후
# 크렘브릴레
# 몽글몽글하다
# 크리스
# 개별
# 잘리다
# 프로슈토
# 접대
# 국내
# 손꼽다
# 빠작
# 능력
# 납득
# 찌석
# 에서라도
# 두런두런
# 눈높이
# 천도
# 인스타그램
# 쟌맛
# 청울
# 카페오레
# 솔티드올리바
# 쩔어요
# 달걀
# 딸기샌드
# 손수
# 버시
# 놨는데
# 포지
# 소형견
# 치르다
# 겉면
# 포트
# 중화
# 초도
# 꽂다
# 놀란
# 벌다
# 안식처
# 심해지다
# 티포트
# 틀리다
# 당근
# 리뉴얼
# 꼬냑
# 풀림
# 따스운
# 복지
# 유정
# 정비
# 으로가
# 보증
# 하루빨리
# 직잡
# 소식
# 고고씽
# 꾸벅
# 몽실
# 나머지
# 나용
# 반전
# 청귤차
# 뭉실이
# 쫀맛탱
# 쪼꼬
# 만큼의
# 위기
# 스플레
# 카와이
# 지금껏
# 부들
# 찰랑
# 헤헤
# 진통
# 헬입니
# 길동
# 호점
# 폭닥폭닥해
# 명색
# 알림
# 것임
# 도터스
# 이내
# 달구
# 물리
# 무색
# 편입
# 개월
# 뽕실뽕실
# 브륄레라테
# 쫀득합니
# 핥다
# 껍질
# 기네
# 꼬옥
# 네요
# 미안하다
# 메타몽
# 보라색
# 순서
# 수플래
# 아빠
# 콕콕
# 유령
# 자자하다
# 이루
# 특집
# 가운데
# 밤향
# 까지가
# 영어
# 한결같이
# 마태
# 막차
# 헤어지다
# 옙뿨
# 구황
# 작물
# 튀어
# 기요
# 지하철
# 심다
# 패드
# 흑백
# 요리사
# 거북
# 브금
# 고풍
# 토터스수플레
# 퐁실퐁
# 거부
# 삼십
# 미도
# 모찌스플레
# 자라
# 느리다
# 조용조
# 말랑쫀득
# 비지
# 보들쫀득
# 번복
# 무질서
# 낭비
# 비비큐
# 무서움
# 광고
# 별개
# 말차스플레
# 딸기스플레
# 온수
# 그랬는데
# 는커녕
# 협조
# 해리포터
# 이애
# 엘리
# 꽈배기
# 주얼
# 유독
# 연차
# 치케
# 지역
# 자트
# 오락가락
# 구들
# 공익
# 목적
# 어찌나
# 떨어뜨리다
# 존재
# 티보
# 냅킨
# 널브러져
# 속옷
# 맛차
# 인물
# 확대
# 유리창
# 남김없이
# 인터
# 바케
# 스크린
# 플랜
# 테리어
# 각층
# 하수
# 고역
# 독트기
# 지키다
# 빙글빙글
# 대세
# 고루느
# 물소
# 외형
# 조심스럽다
# 장애
# 무인
# 일부
# 역할
# 금연
# 말복
# 뽀또
# 레드베리
# 빅토리아
# 라야
# 벽돌
# 쪼끔
# 무가
# 자동
# 문과
# 일용
# 커드
# 호에
# 버터케이크
# 강하
# 뽀또치즈
# 개또
# 밤티
# 공자
# 느좋입니
# 느좋
# 나눔
# 금값
# 별미
# 키치
# 냉동
# 수박도
# 사이다
# 조카
# 육질
# 갈리다
# 무언가
# 오렛
# 국가
# 뷔페
# 친언니
# 성도
# 메너
# 연연
# 후르츠
# 소화도
# 깡페
# 성과
# 맛보기
# 해외여행
# 오이랑
# 기름기
# 츄리
# 문화
# 한화
# 팬이셔
# 장담
# 시크릿
# 태어나다
# 텁텁하
# 백종원
# 천상
# 사이사이
# 정통
# 방송
# 적당
# 정감
# 리지
# 들키다
# 이웃집
# 찰스
# 디아나
# 우스벡
# 미녀
# 핵인
# 싸이
# 거저
# 끊다
# 린치
# 인과
# 프루츠
# 바틀
# 지중해
# 스푼
# 스틸
# 본토
# 비결
# 감히
# 무심
# 아르메니아
# 매다
# 슴슴
# 시도
# 돈길
# 미츠따이
# 줜맛탱
# 세우다
# 멜랑꼴리
# 미스
# 위트
# 혼술

# %% [markdown]
# - 3회 이하로 나온 단어들 일단 삭제!! .. 이것도 상의해봐야 할듯하다.

# %%
minimum_count = 3
more_than_one_time= []
for i in tqdm(range(len(remove_stopwords))):
    tmp = remove_stopwords[i]
    if remove_stopwords.count(tmp) >= minimum_count:
        more_than_one_time.append(tmp)
# Out:
# 100%|██████████| 60499/60499 [01:33<00:00, 649.53it/s]

# %%
len(more_than_one_time)
# Out:
# 57069

# %%
text = set(more_than_one_time)

# %%
# CountVectorizer 객체 생성 (필요에 따라 추가 파라미터 조정 가능)
vectorizer = CountVectorizer()

# 리뷰 데이터를 CountVectorizer로 변환
data_features = vectorizer.fit_transform(df['clean_review'].tolist())

# %%
# TF-IDF 변환기 생성 및 데이터 변환
tfidf_vectorizer = TfidfTransformer()
tf_idf_vect = tfidf_vectorizer.fit_transform(data_features)

# 단어 인덱스와 단어를 매핑하는 사전 생성
vocab = {v: k for k, v in vectorizer.vocabulary_.items()}

# 출력 확인
print("단어와 인덱스 매핑:", vocab)
print("TF-IDF Matrix Shape:", tf_idf_vect.shape)
# Out:
# 단어와 인덱스 매핑: {6418: '분위기도', 2217: '너무', 11719: '좋고', 3701: '따뜻한', 1045: '공간이에요', 11208: '재방문', 10390: '의사', 10819: '입니다', 13259: '카페', 13400: '커피도', 4644: '맛있습니다', 4650: '맛있어요', 14971: '해방촌', 4807: '매장도', 1680: '깔끔하고', 13171: '친절하시고', 6412: '분위기가', 11737: '좋아요', 13630: '크리스마스라', 14036: '트리랑', 4124: '리스들로', 1793: '꾸며져', 10849: '있고', 1931: '나무로', 13907: '테이블이', 11639: '조화로워요', 11014: '자주', 9560: '오는', 3250: '동네', 13316: '카페예요', 13391: '커피', 4617: '맛있고', 8480: '아늑합니다', 11850: '주로', 15201: '혼자', 9875: '와서', 9158: '업무하는데요', 14360: '평일은', 11607: '조용하고', 11864: '주말은', 6912: '사람이', 4413: '많아요', 1476: '근처에', 6268: '볼일이', 10884: '있어', 10063: '우연치', 8814: '않게', 3471: '들렀는데', 5299: '무드', 11804: '좋은', 13291: '카페를', 12642: '찾아서', 11259: '저는', 15095: '행운아입니다', 9592: '오래오래', 5986: '번창하세요', 13260: '카페가', 8472: '아늑하고', 11614: '조용해서', 13406: '커피랑', 3637: '디저트도', 4626: '맛있네요', 6437: '분위기의', 12666: '찾으시다면', 12960: '추천드립니다', 13392: '커피가', 10506: '이뻐요', 8483: '아늑해요', 15184: '호지티', 11754: '좋아하는데', 3946: '라테로', 4961: '먹을', 10886: '있어서', 2872: '담에', 12828: '초코바나나', 13743: '타르트', 4951: '먹으러', 9777: '올게요', 6411: '분위기', 4666: '맛있었어요', 6907: '사람에', 13095: '치여', 3229: '돌아다니다', 12616: '찾아', 10065: '우연히', 3552: '들어온', 1013: '곳인데', 13048: '취향', 11240: '저격', 11604: '조용', 12493: '차분', 2552: '느낌의', 8758: '안정감을', 11844: '주는', 1008: '곳이에요', 5103: '메이플피칸', 15374: '휘낭시에', 8659: '아이스아메리카노와', 15185: '호지티라테', 8054: '시킨', 5152: '모두', 4663: '맛있었습니다', 2669: '다음에', 595: '거예요', 1472: '근처', 8476: '아늑한', 3940: '라테가', 4679: '맛있을', 450: '같아서', 3464: '들러보았습니다', 3646: '디저트랑', 2220: '너무너무', 4363: '만족스러워요', 11611: '조용한', 6435: '분위기와', 3697: '따뜻하네요', 13144: '친구랑', 14985: '해방촌으로', 4266: '마지막', 170: '가을을', 12102: '즐기러', 9926: '왔다가', 12947: '추워서', 2543: '느낌', 1905: '나는', 5823: '방문하고', 8285: '싶어서', 11789: '좋았어요', 2263: '넘나', 4614: '맛있게', 4939: '먹었습니다', 11487: '정성스럽고', 8623: '아아', 13272: '카페도', 9476: '예쁘고', 6997: '사장님도', 13163: '친절하세요', 8523: '아담하고', 10512: '이쁘고', 4527: '맛나요', 5948: '버터', 14256: '페퍼라테', 899: '고소하고', 14980: '해방촌에서', 9027: '어디', 254: '갈까', 889: '고민하다가', 13638: '크림', 9832: '올려져', 10859: '있는', 2889: '당겨서', 9922: '왔는데', 10557: '이야기하기도', 7009: '사장님이', 9465: '예뻐요', 4867: '먹고', 349: '갑니다', 8559: '아메리카노', 10122: '원두가', 4257: '마일드하고', 8391: '쑥크럼블', 8746: '안에', 3830: '떡이', 3509: '들어', 6226: '보통', 15379: '휘낭시에랑', 2638: '다른', 4534: '맛남이', 10858: '있네요', 1021: '공간도', 8477: '아늑한데', 10214: '위치가', 2645: '다소', 8927: '애매해서', 9593: '오래전부터', 6043: '벼루다가', 3407: '드디어', 9874: '와봤어요', 4846: '머무르기', 452: '같아요', 3026: '대화하기에도', 11052: '작업하기에도', 984: '곳은', 6892: '사람', 4399: '많고', 7919: '시끄러운데', 9276: '여기', 9336: '여유로워서', 448: '같습니다', 10711: '인테리어도', 316: '감성', 2279: '넘치고', 10324: '음료도', 5600: '바쁜', 10006: '요즘이었어서', 14754: '하루', 9329: '여유', 433: '갖는', 555: '거라', 12601: '찾고', 975: '곳만큼', 1560: '기대가', 13452: '컸는데', 1559: '기대', 10533: '이상으로', 13164: '친절하셔서', 10799: '읽으려고', 2319: '노래', 7516: '소리도', 11318: '적당해서', 15460: '힐링하다가', 14085: '특히', 3943: '라테는', 11513: '제가', 4896: '먹어', 7908: '시그니처', 3939: '라테', 173: '가장', 10706: '인테리어가', 9463: '예뻐서', 9550: '오고', 8291: '싶었는데', 9363: '역시나', 7813: '스타일이에요', 6990: '사장님', 11467: '정말', 3649: '디저트류', 11286: '저번에', 3023: '대화하기', 11735: '좋아서', 12655: '찾아왔어요', 10371: '음악', 7353: '선곡도', 11075: '잔잔하니', 12315: '집중하기', 11723: '좋네요', 15186: '호지티라테도', 8287: '싶어요', 5499: '밀크티', 4815: '매장이', 9570: '오늘은', 7634: '수다를', 10229: '위해', 9938: '왔지만', 2664: '다음', 3789: '때는', 11055: '작업할', 3790: '때도', 10231: '위해서도', 5846: '방문할', 9539: '예정입니다', 295: '감사해요', 10374: '음악도', 1042: '공간이었습니다', 15378: '휘낭시에도', 9941: '왕맛났어요', 6995: '사장님께서', 9880: '와야겠어요', 5081: '메뉴인데', 14257: '페퍼라테가', 8133: '신기해서', 4223: '마시러', 9932: '왔어요', 2798: '달달해요', 4805: '매장', 10964: '자리도', 14329: '편해요', 7832: '스토리지앤북앤', 14678: '필름', 9715: '오픈', 1545: '기다리느라', 11105: '잠깐', 3487: '들렸는데', 8533: '아래', 6659: '비스킷', 6348: '부분이', 1394: '그래놀라인', 447: '같더라고요', 2179: '내부도', 12494: '차분하고', 11824: '좌석은', 11452: '정도였어요', 3634: '디저트가', 12361: '짱짱입니다', 8172: '신흥', 8009: '시장', 9675: '오실', 10914: '있으시면', 5354: '무조건이에요', 5553: '바나나초코타르트랑', 92 ...
# TF-IDF Matrix Shape: (8728, 15504)

# %% [markdown]
# - 본격 키워드 추출
# - 이 사이에 긍부정으로 나누는 과정 있으면 좋을 듯 하다.

# %% [markdown]
# - 그 다음에 긍정, 부정 별로 키워드... 왜 이 걸 선택했는지... 카페별로! 있으면 좋을듯.
# - 나는 지금 전체에 대해서 했지만, 카페별로 해야될듯 하다 ^.^
# - 즉 하... 아냐 걍 여기서 멈춰..................
